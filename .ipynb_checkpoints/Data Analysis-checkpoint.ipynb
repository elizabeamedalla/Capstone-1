# %% [markdown]
# # DATA WRANGLING: CRIME RATES IN NYC

# %% [markdown]
# ## Import packages and data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set_style("darkgrid")

df = pd.read_csv('final_NYC_crimes.csv')

# %%
df.head()
# Out:
#    CMPLNT_NUM  DISTRICT    BOROUGH        DATE      TIME OFFENSE LEVEL  \
# 0   900735981       105     QUEENS  2019-01-01  15:00:00     VIOLATION
# 1   495588128        44      BRONX  2019-01-01  18:35:00        FELONY
# 2   876271073        88   BROOKLYN  2019-01-01   1:00:00        FELONY
# 3   394629573        44      BRONX  2019-01-01  15:15:00        FELONY
# 4   579035297        18  MANHATTAN  2019-01-01   2:10:00        FELONY
#
#   LOC_OF_OCCUR_DESC                   OFFENSE_NAME SUSP_AGE_GROUP  \
# 0          FRONT OF                    HARRASSMENT            NaN
# 1               NaN  OFFENSES_AGAINST_PUBLIC_ORDER            NaN
# 2            INSIDE                        LARCENY            NaN
# 3               NaN  OFFENSES_AGAINST_PUBLIC_ORDER          25-44
# 4            INSIDE                        ASSAULT        UNKNOWN
#
#         SUSP_RACE  ...                  VIC_RACE VIC_SEX X_COORD_CD  \
# 0             NaN  ...  ASIAN / PACIFIC ISLANDER       F    1056264
# 1             NaN  ...                   UNKNOWN       E    1004749
# 2             NaN  ...                     WHITE       F     990026
# 3  WHITE HISPANIC  ...                   UNKNOWN       E    1004749
# 4           BLACK  ...            WHITE HISPANIC       M     987374
#
#   Y_COORD_CD   Latitude  Longitude                                   Lat_Lon  \
# 0     205572  40.730639 -73.740167  (40.730639403000055, -73.74016656399994)
# 1     240880  40.827820 -73.925931  (40.827819901000055, -73.92593075599996)
# 2     189746  40.687492 -73.979174  (40.687492038000066, -73.97917448199998)
# 3     240880  40.827820 -73.925931  (40.827819901000055, -73.92593075599996)
# 4     217550  40.763809 -73.988724  (40.763808604000076, -73.98872409799998)
#
#    YEAR MONTH  DAY
# 0  2019     1    1
# 1  2019     1    1
# 2  2019     1    1
# 3  2019     1    1
# 4  2019     1    1
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Convert Dates to DateTime format

# %%
df['DATE'] = pd.to_datetime(df['DATE'])

# %% [markdown]
# # DATA STORYTELLING: CRIME RATES IN NYC

# %% [markdown]
# The purpose of this project is to be able to understand the nature of crimes that happen in NYC in each borough. Various crimes could be confined to different boroughs.
#
# I performed some data exploration and visualization in this notebook with the hope of uncovering some interesting insights along the way. I used publicly available data to explore crime in NYC from January 2019 to December 2019. The data is available from the NYC's data portal linked below.
#
# https://data.cityofnewyork.us/Public-Safety/NYPD-Complaint-Data-Current-Year-To-Date-/5uac-w243/data
#
# Though the original audience is the NYPD cops and detectives, the audience could be any New York City's resident with minimum knowledge of the technicalities of the code cells. There are comment in each cell codes to explain what steps I took to obtain the results.

# %% [markdown]
# ## Display amount of Crimes per borough in the data set

# %%
borough_count = df.BOROUGH.value_counts()
borough_count.plot(kind='pie', y = 'BOROUGH', shadow=False,autopct='%1.1f%%', legend = False)
borough_count
# Out:
# BROOKLYN         129370
# MANHATTAN        113650
# BRONX             99002
# QUEENS            90147
# STATEN ISLAND     18510
# UNKNOWN             299
# Name: BOROUGH, dtype: int64

# %% [markdown]
# We counted the ratio of crimes in each borough to the total crimes reported and did a pie plot. Brooklyn had the highest reported crimes but it was not too far of a difference from Manhattan, Bronx and Queens.

# %% [markdown]
# ## Plot frequency of crimes for each borough in 2019
# I want to see the trend of crimes reported every month in each borough. Is there peak season for crimes? When is the crime reported lowest? To see the bigger picture, I made time series plot for all the boroughs in each month.

# %%
# create subset df
boro_2019 = df[['MONTH', 'BOROUGH']]
boro_2019 = boro_2019[boro_2019.BOROUGH != 'UNKNOWN']
boro_2019
# Out:
#         MONTH        BOROUGH
# 0           1         QUEENS
# 1           1          BRONX
# 2           1       BROOKLYN
# 3           1          BRONX
# 4           1      MANHATTAN
# ...       ...            ...
# 450973     12       BROOKLYN
# 450974     12          BRONX
# 450975     12       BROOKLYN
# 450976     12  STATEN ISLAND
# 450977     12          BRONX
#
# [450679 rows x 2 columns]

# %% [markdown]
# ### Plot the frequency of crimes reported in all boroughs in one graph.

# %%
# use unstack() to create the dataframe of crimes for each borough per month
#Grouping
month_boro = boro_2019.groupby(['MONTH','BOROUGH'])
crimes_per_borough = month_boro["MONTH"].count().unstack()
crimes_per_borough
# Out:
# BOROUGH  BRONX  BROOKLYN  MANHATTAN  QUEENS  STATEN ISLAND
# MONTH
# 1         7874     10600       8823    7016           1506
# 2         6956      9160       7889    6387           1355
# 3         7987     10500       8996    7308           1477
# 4         7979     10436       9228    7086           1499
# 5         8817     11516       9953    8046           1674
# 6         8477     11383      10163    7991           1665
# 7         9331     12108      10392    8461           1721
# 8         9017     11566      10292    8191           1548
# 9         8694     11499      10198    7767           1691
# 10        8507     11179      10136    7675           1635
# 11        7930     10101       9106    7400           1422
# 12        7433      9322       8474    6819           1317

# %%
# Plot the df
fig, ax = plt.subplots(figsize=(10,5))
crimes_per_borough.plot(ax=ax, title="Crimes per Borough each month", legend=False)
ax.set(xlabel="MONTHS", ylabel="# of Crimes")

# Customize Legend
ax.legend(loc='center', frameon=True, ncol=2)

# %% [markdown]
# The trends of crimes reported are similar and consistent throughout the year for each borough. Brooklyn has been consistently on top. For more details, I made the time series plots of each borough.

# %% [markdown]
# ### Plot time series of Bronx in 2019

# %%
#create subset df with only 2 columns
boro_2019 = df[['DATE', 'BOROUGH', 'MONTH']]

boro_2019 = boro_2019[boro_2019.BOROUGH != 'UNKNOWN']

#Create the filter
bronx = boro_2019[boro_2019['BOROUGH'] == 'BRONX']

# Count the sum of occurences for each date
bronx = bronx.DATE.value_counts()

# Use resample to organize it into monthly sums
bronx = bronx.resample(rule='M').apply('sum')

# Plot
bronx.plot(kind='line', title = "BRONX")

# %% [markdown]
# ### Plot Manhattan in 2019

# %%
manhattan = boro_2019[boro_2019['BOROUGH'] == 'MANHATTAN']
manhattan = manhattan.DATE.value_counts()
manhattan = manhattan.resample(rule='M').apply('sum')
manhattan.plot(kind='line', title="MANHATTAN")

# %% [markdown]
# ### Plot Queens in 2019

# %%
queens = boro_2019[boro_2019['BOROUGH'] == 'QUEENS']
queens = queens.DATE.value_counts()
queens = queens.resample(rule='M').apply('sum')
queens.plot(kind='line', title="QUEENS")

# %% [markdown]
# ### Plot Staten Island in 2019

# %%
staten_island = boro_2019[boro_2019['BOROUGH'] == 'STATEN ISLAND']
staten_island = staten_island.DATE.value_counts()
staten_island = staten_island.resample(rule='M').apply('sum')
staten_island.plot(kind='line', title="STATEN ISLAND")

# %% [markdown]
# All boroughs have a noticeable drop rate in February. Summer seems to be the peak season for crimes, starting in May and the highest and dropping starts in October. The highest crime reported happened in July and lowest are February and December.

# %% [markdown]
# ## Make a Stacked Bar Graph of Crimes per Borough in 2019
# I want to visualize the distibution of crimes reported in each borough per month.

# %%
# df2 = boro_2019.groupby(['MONTH', 'BOROUGH'])['MONTH'].count().unstack('BOROUGH').fillna(0)
# df2.plot(kind='bar',legend="best", stacked=True, figsize=(10,10))
# df2.info

# TODO: use line chart for this

# %% [markdown]
# ## Get the frequency of top 10 districts with most crimes.
# NYC is one of the most densely populated cities in the US so no doubt, crimes are reported in all parts of NYC. Now that we have the crime data for each borough, I want to break it down and see the top 10 districts with the most crimes reported.

# %%
# TODO: create another column where district and borough are combined in one column
district_borough = df[["DISTRICT", "BOROUGH"]].copy()
district_borough['DISTRICT_BOROUGH'] = df.apply(lambda x: f"{x['DISTRICT']}, {x['BOROUGH']}", axis=1)
district_borough

# Get the top 10 districts with highest frequencies of crimes reported
district_crimes = district_borough.DISTRICT_BOROUGH.value_counts().head(10)

#Sort in descending order
district_crimes = district_crimes.sort_values(ascending=True)
district_crimes
# Out:
# 67, BROOKLYN      8593
# 73, BROOKLYN      9010
# 43, BRONX         9309
# 46, BRONX         9393
# 47, BRONX         9468
# 14, MANHATTAN     9547
# 52, BRONX         9710
# 44, BRONX        11440
# 40, BRONX        12813
# 75, BROOKLYN     13936
# Name: DISTRICT_BOROUGH, dtype: int64

# %%
# Plot Crimes per District using horizontal bar chart
ax = district_crimes.plot(kind='barh', title="Crimes per District")
ax.set(xlabel="Number of Crimes", ylabel="District")
# Out:
# [Text(0, 0.5, 'District'), Text(0.5, 0, 'Number of Crimes')]

# %% [markdown]
# // TODO: fix analysis
#
# The top district with most crimes is Disrict 75 in Manhattan, and the following districts are in Brooklyn.

# %% [markdown]
# ## Make a Map of Total Crimes per District in 2019
# To visualize the crime data per district, we can use `sns.lmplot` to make the scatter plot of crimes reported per district. Just to clarify, this is not the exact map of NYC. This is a scatter plot based on the exact location of the occurence of the crime reported per X and Y coordinate of the crime data. There might be parts of NYC that is not dotted here since no crime was reported.

# %%
df_coord = df.loc[(df['X_COORD_CD']!=0)]

sns.lmplot('X_COORD_CD',
           'Y_COORD_CD',
           data=df_coord,
           fit_reg=False, 
           hue="DISTRICT", 
           palette='Dark2',
           height=12,
           ci=2,
           legend=False,
           scatter_kws={"marker": "D", 
                        "s": 10}) 
ax = plt.gca()
ax.set_title("ALL CRIMES REPORTED PER DISTRICT 2019")
# Out:
# Text(0.5, 1, 'ALL CRIMES REPORTED PER DISTRICT 2019')

# %% [markdown]
# ## Make a map of the most frequent crime in each district

# %%
# Implementing first solution from http://stackoverflow.com/questions/45161355/pandas-dataframe-find-the-max-after-groupby-two-columns-and-gaet-counts
# Make a groupby using DISTRICT and OFFENSE_NAME Column. 
# Set `as_index=False` so that the index is int and not the DISTRICT column. 
# `as_index=False` is what separates the groupby into individual rows. Try making it True.
# We want it as individual rows because of how we will use that shape to determine the most frequent crime in each District.
top_crime_in_districts = df.groupby(['DISTRICT', 'OFFENSE_NAME'], as_index=False)['CMPLNT_NUM'].count()
top_crime_in_districts
# Out:
#       DISTRICT             OFFENSE_NAME  CMPLNT_NUM
# 0            1                    ARSON           1
# 1            1                  ASSAULT         541
# 2            1                 BURGLARY         141
# 3            1  DRIVING_UNDER_INFLUENCE          16
# 4            1                  FORGERY          54
# ...        ...                      ...         ...
# 1448       123               SEX_CRIMES          21
# 1449       123    SOCIAL_RELATED_CRIMES           7
# 1450       123                    THEFT          74
# 1451       123   TRAFFIC_LAWS_VIOLATION          25
# 1452       123             UNCLASSIFIED          16
#
# [1453 rows x 3 columns]

# %%
# Create a second groupby of the previous groupby.
# This groupby uses only the DISTRICT column. 
# This will create groups for each District 1-123. 
districts = top_crime_in_districts.groupby('DISTRICT')
list(districts)
# Out:
# [(1,     DISTRICT                      OFFENSE_NAME  CMPLNT_NUM
#   0          1                             ARSON           1
#   1          1                           ASSAULT         541
#   2          1                          BURGLARY         141
#   3          1           DRIVING_UNDER_INFLUENCE          16
#   4          1                           FORGERY          54
#   5          1                       HARRASSMENT         769
#   6          1                          HOMICIDE          70
#   7          1                           LARCENY        3316
#   8          1                            MURDER           1
#   9          1     OFFENSES_AGAINST_PUBLIC_ORDER         947
#   10         1  POSSESSION_CONTROLLED_SUBSSTANCE          40
#   11         1                 POSSESSION_WEAPON          26
#   12         1                           ROBBERY          78
#   13         1                        SEX_CRIMES          99
#   14         1             SOCIAL_RELATED_CRIMES           6
#   15         1                             THEFT         309
#   16         1            TRAFFIC_LAWS_VIOLATION          67
#   17         1                      UNCLASSIFIED           5),
#  (5,     DISTRICT                      OFFENSE_NAME  CMPLNT_NUM
#   18         5                             ARSON           9
#   19         5                           ASSAULT         799
#   20         5                          BURGLARY         100
#   21         5           DRIVING_UNDER_INFLUENCE          17
#   22         5                           FORGERY          23
#   23         5                       HARRASSMENT         634
#   24         5                          HOMICIDE          87
#   25         5                           LARCENY        1562
#   26         5                            MURDER           4
#   27         5     OFFENSES_AGAINST_PUBLIC_ORDER         625
#   28         5  POSSESSION_CONTROLLED_SUBSSTANCE         112
#   29         5                 POSSESSION_WEAPON          24
#   30         5                           ROBBERY          91
#   31         5                        SEX_CRIMES         106
#   32         5             SOCIAL_RELATED_CRIMES           3
#   33         5                             THEFT         184
#   34         5            TRAFFIC_LAWS_VIOLATION          60
#   35         5                      UNCLASSIFIED         141),
#  (6,     DISTRICT                      OFFENSE_NAME  CMPLNT_NUM
#   36         6                           ASSAULT         550
#   37         6                          BURGLARY         158
#   38         6           DRIVING_UNDER_INFLUENCE          26
#   39         6                           FORGERY          49
#   40         6                       HARRASSMENT         492
#   41         6                          HOMICIDE          84
#   42         6                        KIDNAPPING           1
#   43         6                           LARCENY        2382
#   44         6     OFFENSES_AGAINST_PUBLIC_ORDER         623
#   45         6  POSSESSION_CONTROLLED_SUBSSTANCE         295
#   46         6                 POSSESSION_WEAPON          36
#   47         6                           ROBBERY         142
#   48         6                        SEX_CRIMES          64
#   49         6             SOCIAL_RELATED_CRIMES           3
#   50         6                             THEFT         121
#   51         6            TRAFFIC_LAWS_VIOLATION          48),
#  (7,     DISTRICT                      OFFENSE_NAME  CMPLNT_NUM
#   52         7                             ARSON           5
#   53         7                           ASSAULT         752
#   54         7                          BURGLARY          95
#   55         7           DRIVING_UNDER_INFLUENCE          28
#   56         7                           FORGERY          44
#   57         7                       HARRASSMENT         598
#   58         7                          HOMICIDE          67
#   59         7                        KIDNAPPING           2
#   60         7                           LARCENY        1248
#   61         7     OFFENSES_AGAINST_PUBLIC_ORDER         773
#   62         7  POSSESSION_CONTROLLED_SUBSSTANCE          71
#   63         7                 POSSESSION_WEAPON          59
#   64         7                           ROBBERY         149
#   65         7                        SEX_CRIMES          56
#   66         7             SOCIAL_RELATED_CRIMES           6
#   67         7                             THEFT         105
#   68         7            TRAFFIC_LAWS_VIOLATION          53
#   69         7                      UNCLASSIFIED           3),
#  (9,     DISTRICT                      OFFENSE_NAME  CMPLNT_NUM
#   70         9                             ARSON           7
#   71         9                           ASSAULT         670
#   72         9                          BURGLARY         129
#   73         9           DRIVING_UNDER_INFLUENCE           8
#   74         9                           FORGERY          22
#   75         9                       HARRASSMENT         614
#   76         9                          HOMICIDE          85
#   77         9                           LARCENY        2057
#   78         9                            MURDER           3
#   79         9     OFFENSES_AGAINST_PUBLIC_ORDER         656
#   80         9  POSSESSION_CONTROLLED_SUBSSTANCE         163
#   81         9                 POSSESSION_WEAPON          46
#   82         9                           ROBBERY         119
#   83         9                        SEX_CRIMES          80
#   84         9             SOCIAL_RELATED_CRIMES           6
#   85         9                             THEFT          99
#   86         9            TRAFFIC_LAWS_VIOLATION          49
#   87         9                      UNCLASSIFIED           5),
#  (10,      DISTRICT                      OFFENSE_NAME  CMPLNT_NUM
#   88         10                             ARSON           2
#   89         10                           ASSAULT         493
#   90         10                          BURGLARY          87
#   91         10           DRIVING_UNDER_INFLUENCE          78
#   92         10                           FORGERY          29
#   93         10                       HARRASSMENT         542
#   94         10                          HOMICIDE          59
#   95         10                        KIDNAPPING           1
#   96         10                           LARCENY        1621
#   97         10     OFFENSES_AGAINST_PUBLIC_ORDER         609
#   98         10  POSSESSION_CONTROLLED_SUBSSTANCE          97
#   99         10                 POSSESSION_WEAPON          37
#   100        10                           ROBBERY         122
#   101        10                        SEX_CRIMES          72
#   102        10             SOCIAL_RELATED_CRIMES           6
#   103        10                             THEFT          70
#   104        10            TRAFFIC_LAWS_VIOLATION          65
#   105        10                      UNCLASSIFIED           2),
#  (13,      DISTRICT                      OFFENSE_NAME  CMPLNT_NUM
#   106        13                             ARSON           4
#   107        13                           ASSAULT         777
#   108        13                          BURGLARY         220
#   109        13           DRIVING_UNDER_INFLUENCE          35
#   110        13                           FORGERY          56
#   111        13                       HARRASSMENT         859
#   112        13                          HOMICIDE         103
#   113        13                        KIDNAPPING           1
#   114        13                           LARCENY        3778
#   115        13     OFFENSES_AGAINST_PUBLIC_ORDER         899
#   116        13  POSSESSION_CONTROLLED_SUBSSTANCE         178
#   117        13                 POSSESSION_WEAPON          45
#   118        13                           ROBBERY         166
#   119        13                        SEX_CRIMES         160
#   120        13             SOCIAL_RELATED_CRIMES           8
#   121        13                             THEFT         183
#   122        13            TRAFFIC_LAWS_VIOLATION          79
#   123        13                      UNCLASSIFIED           5),
#  (14,      DISTRICT                      OFFENSE_NAME  CMPLNT_NUM
#   124        14                             ARSON           4
#   125        14                           ASSAULT         960
#   126        14                          BURGLARY         183
#   127        14           DRIVING_UNDER_INFLUENCE          28
#   128        14                           FORGERY         216
#   129        14                          GAMBLING           1
#   130        14                       HARRASSMENT         860
#   131        14                          HOMICIDE         106
#   132        14                        KIDNAPPING           2
#   133        14                           LARCENY        4963
#   134        14     OFFENSES_AGAINST_PUBLIC_ORDER        1057
#   135        14  POSSESSION_CONTROLLED_SUBSSTANCE         406
#   136        14                 POSSESSION_WEAPON          78
#   137        14                           ROBBERY         137
#   138        14                        SEX_CRIMES         231
#   139        14             SOCIAL_RELATED_CRIMES           2
#   140        14                             THEFT         234
#   141        14            TRAFFIC_LAWS_VIOLATION          74
#   142        14                      UNCLASSIFIED           5),
#  (17,      DISTRICT                      OFFENSE_NAME  CMPLNT_NUM
#   143        17                             ARSON           1
#   144        17                           ASSAULT         365
#   145        17                          BURGLARY         101
#   146        17           DRIVING_UNDER_INFLUENCE          13
#   147        17                           FORGERY          34
#   148        17                       HARRASSMENT         486
#   149        17                          HOMICIDE          39
#   150        17                        KIDNAPPING           1
#   151        17                           LARCENY        1869
#   152        17     OFFENSES_AGAINST_PUBLIC_ORDER         370
#   153        17  POSSESSION_CONTROLLED_SUBSSTANCE          44
#   154        17                 POSSESSION_WEAPON          12
#   155        17                           ROBBERY          59
#   156        17                        SEX_CRIMES          64
#   157        17             SOCIAL_RELATED_CRIMES           1
#   158        17                             THEFT         131
#   159        17            TRAFFIC_LAWS_VIOLATION          85
#   160        17                      UNCLASSIFIED           2),
#  (18,      DISTRICT                      OFFENSE_NAME  CMPLNT_NUM
#   161        18                             ARSON           4
#   162        18                           ASSAULT         903
#   163        18                          BURGLARY         170
#   164        18           DRIVING_UNDER_INFLUENCE          25
#   165        18                           FORGERY          62
#   166        18                       HARRASSMENT        1084
#   167        18                          HOMICIDE          66
#   168        18                           LARCENY        3926
#   169        18                            MURDER           1
#   170        18     OFFENSES_AGAINST_PUBLIC_ORDER         874
#   171        18  POSSESSION_CONTROLLED_SUBSSTANCE          77
#   172        18                 POSSESSION_WEAPON          31
#   173        18                           ROBBERY         172
#   174        18                        SEX_CRIMES         158
#   175        18             SOCIAL_RELATED_CRIMES           2
#   176        18                             THEFT         250
#   177        18            TRAFFIC_LAWS_VIOLATION         109
#   178        18                      UNCLASSIFIED           4),
#  (19,      DISTRICT                      OFFENSE_NAME  CMPLNT_NUM
#   179        19                             ARSON           7
#   180        19                           ASSAULT         578
#   181        19                          BURGLARY         223
#   182        19           DRIVING_UNDER_INFLUENCE          16
#   183        19                           FORGERY          66
#   184        19                       HARRASSMENT         831
#   185        19                          HOMICIDE         125
#   186        19                        KIDNAPPING           1
#   187        19                           LARCENY        4200
#   188        19     OFFENSES_AGAINST_PUBLIC_ORDER         721
#   189        19  POSSESSION_CONTROLLED_SUBSSTANCE          26
#   190        19                 POSSESSION_WEAPON          25
#   191        19                           ROBBERY         170
#   192        19                        SEX_CRIMES         108
#   193        19             SOCIAL_RELATED_CRIMES          10
#   194        19                             THEFT         327
#   195        19            TRAFFIC_LAWS_VIOLATION         102
#   196        19                      UNCLASSIFIED           5),
#  (20,      DISTRICT                      OFFENSE_NAME  CMPLNT_NUM
#   197        20                             ARSON           2
#   198        20                           ASSAULT         337
#   199        20                          BURGLARY          77
#   200        20           DRIVING_UNDER_INFLUENCE          13
#   201        20                           FORGERY          11
#   202        20                       HARRASSMENT         536
#   203        20                          HOMICIDE          45
#   204        20                           LARCENY        2166
#   205        20                            MURDER           1
#   206        20     OFFENSES_AGAINST_PUBLIC_ORDER         526
#   207        20  POSSESSION_CONTROLLED_SUBSSTANCE          20
#   208        20                 POSSESSION_WEAPON          10
#   209        20                           ROBBERY          85
#   210        20                        SEX_CRIMES          76
#   211        20             SOCIAL_RELATED_CRIMES           7
#   212        20                             THEFT         135
#   213        20            TRAFFIC_LAWS_VIOLATION          39
#   214        20                      UNCLASSIFIED           2),
#  (22,      DISTRICT                      OFFENSE_NAME  CMPLNT_NUM
#   215        22                             ARSON           1
#   216        22                           ASSAULT          42
#   217        22                          BURGLARY           1
#   218        22           DRIVING_UNDER_INFLUENCE           1
#   219        22                           FORGERY           1
#   220        22                       HARRASSMENT          34
#   221        22                          HOMICIDE           2
#   222        22                           LARCENY          88
#   223        22                            MURDER           1
#   224        22     OFFENSES_AGAINST_PUBLIC_ORDER          34
#   225        22  POSSESSION_CONTROLLED_SUBSSTANCE          11
#   226        22                 POSSESSION_WEAPON           1
#   227        22                           ROBBERY          21
#   228        22                        SEX_CRIMES           8
#   229        22                             THEFT           2
#   230        22            TRAFFIC_LAWS_VIOLATION           2),
#  (23,      DISTRICT                      OFFENSE_NAME  CMPLNT_NUM
#   231        23                             ARSON          17
#   232        23                           ASSAULT        1104
#   233        23                          BURGLARY          79
#   234        23           DRIVING_UNDER_INFLUENCE          24
#   235        23                           FORGERY          65
#   236        23                          GAMBLING          13
#   237        23                       HARRASSMENT         923
#   238        23                          HOMICIDE         161
#   239        23                        KIDNAPPING           1
#   240        23                           LARCENY        1119
#   241        23                            MURDER           2
#   242        23     OFFENSES_AGAINST_PUBLIC_ORDER        1172
#   243        23  POSSESSION_CONTROLLED_SUBSSTANCE         170
#   244        23                 POSSESSION_WEAPON         131
#   245        23                           ROBBERY         167
#   246        23                        SEX_CRIMES         108
#   247        23             SOCIAL_RELATED_CRIMES          10
#   248        23                             THEFT         111
#   249        23            TRAFFIC_LAWS_VIOLATION          70
#   250        23                      UNCLASSIFIED           6),
#  (24,      DISTRICT                      OFFENSE_NAME  CMPLNT_NUM
#   251        24                             ARSON           5
#   252        24                           ASSAULT         519
#   253        24                          BURGLARY         109
#   254        24           DRIVING_UNDER_INFLUENCE          16
#   255        24                           FORGERY          25
#   256        24                          GAMBLING           9
#   257        24                       HARRASSMENT         608
#   258        24                          HOMICIDE          78
#   259        24                        KIDNAPPING           2
#   260        24                           LARCENY        1986
#   261        24                            MURDER           2
#   262        24     OFFENSES_AGAINST_PUBLIC_ORDER         572
#   263        24  POSSESSION_CONTROLLED_SUBSSTANCE          39
#   264        24                 POSSESSION_WEAPON          28
#   265        24                           ROBBERY         172
#   266        24                        SEX_CRIMES          57
#   267        24             SOCIAL_RELATED_CRIMES           5
#   268        24                             THEFT         119
#   269        24            TRAFFIC_LAWS_VIOLATION          29
#   270        24                      UNCLASSIFIED           1),
#  (25,      DISTRICT                      OFFENSE_NAME  CMPLNT_NUM
#   271        25                             ARSON           5
#   272        25                           ASSAULT        1128
#   273        25                          BURGLARY         109
#   274        25           DRIVING_UNDER_INFLUENCE          53
#   275        25                           FORGERY         111
#   276        25                          GAMBLING           5
#   277        25                       HARRASSMENT         810
#   278        25                          HOMICIDE         200
#   279        25                        KIDNAPPING           3
#   280        25                           LARCENY        1753
#   281        25                            MURDER           3
#   282        25     OFFENSES_AGAINST_PUBLIC_ORDER        1110
#   283        25  POSSESSION_CONTROLLED_SUBSSTANCE        1094
#   284        25                 POSSESSION_WEAPON         139
#   285        25                           ROBBERY         172
#   286        25                        SEX_CRIMES         123
#   287        25             SOCIAL_RELATED_CRIMES           8
#   288        25                             THEFT         121
#   289        25            TRAFFIC_LAWS_VIOLATION          92
#   290        25                      UNCLASSIFIED          34),
#  (26,      DISTRICT                      OFFENSE_NAME  CMPLNT_NUM
#   291        26                             ARSON           1
#   292        26                           ASSAULT         392
#   293        26                          BURGLARY          72
#   294        26           DRIVING_UNDER_INFLUENCE          13
#   295        26                           FORGERY          72
#   296        26                          GAMBLING           3
#   297        26                       HARRASSMENT         458
#   298        26                          HOMICIDE          64
#   299        26                           LARCENY        1083
#   300        26                            MURDER           2
#   301        26     OFFENSES_AGAINST_PUBLIC_ORDER         726
#   302        26  POSSESSION_CONTROLLED_SUBSSTANCE          63
#   303        26                 POSSESSION_WEAPON          31
#   304        26                           ROBBERY         127
#   305        26                        SEX_CRIMES          47
#   306        26             SOCIAL_RELATED_CRIMES           6
#   307        26                             THEFT          63
#   308        26            TRAFFIC_LAWS_VIOLATION          22
#   309        26                      UNCLASSIFIED           2),
#  (28,      DISTRICT                      OFFENSE_NAME  CMPLNT_NUM
#   310        28                             ARSON           7
#   311        28                           ASSAULT         885
#   312        28                          BURGLARY          97
#   313        28           DRIVING_UNDER_INFLUENCE          33
#   314        28                           FORGERY          47
#   315        28                          GAMBLING          30
#   316        28                       HARRASSMENT         732
#   317        28                          HOMICIDE         130
#   318        28                        KIDNAPPING           2
#   319        28                           LARCENY        1548
#   320        28                            MURDER           5
#   321        28     OFFENSES_AGAINST_PUBLIC_ORDER         880
#   322        28  POSSESSION_CONTROLLED_SUBSSTANCE         220
#   323        28                 POSSESSION_WEAPON          59
#   324        28                           ROBBERY         163
#   325        28                        SEX_CRIMES          48
#   326        28             SOCIAL_RELATED_CRIMES          12
#   327        28                             THEFT          88
#   328        28            TRAFFIC_LAWS_VIOLATION          45
#   329        28                      UNCLASSIFIED           8),
#  (30,      DISTRICT                      OFFENSE_NAME  CMPLNT_NUM
#   330        30                             ARSON           4
#   331        30                           ASSAULT         617
#   332        30                          BURGLARY          71
#   333        30           DRIVING_UNDER_INFLUENCE          60
#   334        30                           FORGERY          13
#   335        30                          GAMBLING           9
#   336        30                       HARRASSMENT         640
#   337        30                          HOMICIDE          76
#   338        30                           LARCENY        1137
#   339        30                            MURDER           4
#   340        30     OFFENSES_AGAINST_PUBLIC_ORDER         641
#   341        30  POSSESSION_CONTROLLED_SUBSSTANCE          71
#   342        30                 POSSESSION_WEAPON          30
#   343        30                           ROBBERY         190
#   344        30                        SEX_CRIMES          66
#   345        30             SOCIAL_RELATED_CRIMES           7
#   346        30                             THEFT          79
#   347        30            TRAFFIC_LAWS_VIOLATION          40
#   348        30                      UNCLASSIFIED           8),
#  (32,      DISTRICT                      OFFENSE_NAME  CMPLNT_NUM
#   349        32                             ARSON          16
#   350        32                           ASSAULT        1161
#   351        32                          BURGLARY         110
#   352        32           DRIVING_UNDER_INFLUENCE          49
#   353        32                           FORGERY          48
#   354        32                          GAMBLING           5
#   355        32                       HARRASSMENT        1041
#   356        32                          HOMICIDE         194
#   357        32                           LARCENY        1096
#   358        32                            MURDER          10
#   359        32     OFFENSES_AGAINST_PUBLIC_ORDER        1186
#   360        32  POSSESSION_CONTROLLED_SUBSSTANCE         217
#   361        32                 POSSESSION_WEAPON         108
#   362        32                           ROBBERY         217
#   363        32                        SEX_CRIMES          99
#   364        32             SOCIAL_RELATED_CRIMES          22
#   365        32                             THEFT         105
#   366        32            TRAFFIC_LAWS_VIOLATION          63
#   367        32                      UNCLASSIFIED           9),
#  (33,      DISTRICT                      OFFENSE_NAME  CMPLNT_NUM
#   368        33                             ARSON          11
#   369        33                           ASSAULT         640
#   370        33                          BURGLARY         118
#   371        33           DRIVING_UNDER_INFLUENCE          44
#   372        33                           FORGERY          47
#   373        33                          GAMBLING           1
#   374        33                       HARRASSMENT         593
#   375        33                          HOMICIDE         133
#   376        33                        KIDNAPPING           5
#   377        33                           LARCENY        1075
#   378        33                            MURDER           4
#   379        33     OFFENSES_AGAINST_PUBLIC_ORDER         670
#   380        33  POSSESSION_CONTROLLED_SUBSSTANCE         255
#   381        33                 POSSESSION_WEAPON          36
#   382        33                           ROBBERY         144
#   383        33                        SEX_CRIMES          55
#   384        33             SOCIAL_RELATED_CRIMES           9
#   385        33                             THEFT          73
#   386        33            TRAFFIC_LAWS_VIOLATION          60
#   387        33                      UNCLASSIFIED          15),
#  (34,      DISTRICT                      OFFENSE_NAME  CMPLNT_NUM
#   388        34                             ARSON           5
#   389        34                           ASSAULT         892
#   390        34                          BURGLARY         124
#   391        34           DRIVING_UNDER_INFLUENCE          93
#   392        34                           FORGERY          42
#   393        34                       HARRASSMENT         736
#   394        34                          HOMICIDE         110
#   395        34                           LARCENY        1606
#   396        34                            MURDER           6
#   397        34     OFFENSES_AGAINST_PUBLIC_ORDER         866
#   398        34  POSSESSION_CONTROLLED_SUBSSTANCE         137
#   399        34                 POSSESSION_WEAPON          98
#   400        34                           ROBBERY         224
#   401        34                        SEX_CRIMES          81
#   402        34             SOCIAL_RELATED_CRIMES          12
#   403        34                             THEFT         128
#   404        34            TRAFFIC_LAWS_VIOLATION         101
#   405        34                      UNCLASSIFIED           4),
#  (40,      DISTRICT                      OFFENSE_NAME  CMPLNT_NUM
#   406        40                             ARSON          34
#   407        40                           ASSAULT        2454
#   408        40                          BURGLARY         251
#   409        40           DRIVING_UNDER_INFLUENCE          70
#   410        40                           FORGERY         125
#   411        40                          GAMBLING          16
#   412        40                       HARRASSMENT        2003
#   413        40                          HOMICIDE         242
#   414        40                           LARCENY        2555
#   415        40                            MURDER          10
#   416        40     OFFENSES_AGAINST_PUBLIC_ORDER        2251
#   417        40  POSSESSION_CONTROLLED_SUBSSTANCE        1487
#   418        40                 POSSESSION_WEAPON         215
#   419        40                           ROBBERY         471
#   420        40                        SEX_CRIMES         174
#   421        40             SOCIAL_RELATED_CRIMES          55
#   422        40                             THEFT         213
#   423        40            TRAFFIC_LAWS_VIOLATION         185
#   424        40                      UNCLASSIFIED          15),
#  (41,      DISTRICT                      OFFENSE_NAME  CMPLNT_NUM
#   425        41                             ARSON          25
#   426        41                           ASSAULT         996
#   427        41                          BURGLARY         119
#   428        41           DRIVING_UNDER_INFLUENCE          32
#   429        41                           FORGERY          35
#   430        41                          GAMBLING          18
#   431        41                       HARRASSMENT         894
#   432        41                          HOMICIDE         205
#   433        41                        KIDNAPPING           2
#   434        41                           LARCENY        1191
#   435        41                            MURDER           4
#   436        41     OFFENSES_AGAINST_PUBLIC_ORDER        1194
#   437        41  POSSESSION_CONTROLLED_SUBSSTANCE         204
#   438        41                 POSSESSION_WEAPON          83
#   439        41                           ROBBERY         165
#   440        41                        SEX_CRIMES         102
#   441        41             SOCIAL_RELATED_CRIMES          23
#   442        41                             THEFT          67
#   443        41            TRAFFIC_LAWS_VIOLATION         105
#   444        41                      UNCLASSIFIED           4),
#  (42,      DISTRICT                      OFFENSE_NAME  CMPLNT_NUM
#   445        42                             ARSON          26
#   446        42                           ASSAULT        1753
#   447        42                          BURGLARY         204
#   448        42           DRIVING_UNDER_INFLUENCE          33
#   449        42                           FORGERY          37
#   450        42                          GAMBLING           6
#   451        42                       HARRASSMENT        1547
#   452        42                          HOMICIDE         125
#   453        42                        KIDNAPPING           2
#   454        42                           LARCENY        1582
#   455        42                            MURDER          12
#   456        42     OFFENSES_AGAINST_PUBLIC_ORDER        1478
#   457        42  POSSESSION_CONTROLLED_SUBSSTANCE         308
#   458        42                 POSSESSION_WEAPON         150
#   459        42                           ROBBERY         285
#   460        42                        SEX_CRIMES         120
#   461        42             SOCIAL_RELATED_CRIMES          42
#   462        42                             THEFT         165
#   463        42            TRAFFIC_LAWS_VIOLATION         134
#   464        42                      UNCLASSIFIED          10),
#  (43,      DISTRICT                      OFFENSE_NAME  CMPLNT_NUM
#   465        43                             ARSON          28
#   466        43                           ASSAULT        1977
#   467        43                          BURGLARY         142
#   468        43           DRIVING_UNDER_INFLUENCE          38
#   469        43                           FORGERY          62
#   470        43                          GAMBLING           1
#   471        43                       HARRASSMENT        1729
#   472        43                          HOMICIDE         195
#   473        43                        KIDNAPPING           6
#   474        43                           LARCENY        2213
#   475        43                            MURDER           5
#   476        43     OFFENSES_AGAINST_PUBLIC_ORDER        1688
#   477        43  POSSESSION_CONTROLLED_SUBSSTANCE         227
#   478        43                 POSSESSION_WEAPON         139
#   479        43                           ROBBERY         357
#   480        43                        SEX_CRIMES         148
#   481        43             SOCIAL_RELATED_CRIMES          49
#   482        43                             THEFT         126
#   483        43            TRAFFIC_LAWS_VIOLATION         160
#   484        43                      UNCLASSIFIED          25),
#  (44,      DISTRICT                      OFFENSE_NAME  CMPLNT_NUM
#   485        44                             ARSON          15
#   486        44                           ASSAULT        2492
#   487        44                          BURGLARY         174
#   488        44           DRIVING_UNDER_INFLUENCE          25
#   489        44                           FORGERY         191
#   490        44                          GAMBLING           1
#   491        44                       HARRASSMENT        1877
#   492        44                          HOMICIDE         210
#   493        44                        KIDNAPPING           6
#   494        44                           LARCENY        2543
#   495        44                            MURDER           7
#   496        44     OFFENSES_AGAINST_PUBLIC_ORDER        2144
#   497        44  POSSESSION_CONTROLLED_SUBSSTANCE         404
#   498        44                 POSSESSION_WEAPON         240
#   499        44                           ROBBERY         427
#   500        44                        SEX_CRIMES         174
#   501        44             SOCIAL_RELATED_CRIMES          37
#   502        44                             THEFT         252
#   503        44            TRAFFIC_LAWS_VIOLATION         190
#   504        44                      UNCLASSIFIED          38),
#  (45,      DISTRICT                      OFFENSE_NAME  CMPLNT_NUM
#   505        45                             ARSON           7
#   506        45                           ASSAULT         964
#   507        45                          BURGLARY          99
#   508        45           DRIVING_UNDER_INFLUENCE          86
#   509        45                           FORGERY          20
#   510        45                       HARRASSMENT        1109
#   511        45                          HOMICIDE          84
#   512        45                        KIDNAPPING           3
#   513        45                           LARCENY        1812
#   514        45                            MURDER           3
#   515        45     OFFENSES_AGAINST_PUBLIC_ORDER        1131
#   516        45  POSSESSION_CONTROLLED_SUBSSTANCE          80
#   517        45                 POSSESSION_WEAPON          36
#   518        45                           ROBBERY         142
#   519        45                        SEX_CRIMES          61
#   520        45             SOCIAL_RELATED_CRIMES          12
#   521        45                             THEFT          75
#   522        45            TRAFFIC_LAWS_VIOLATION          83
#   523        45                      UNCLASSIFIED           2),
#  (46,      DISTRICT                      OFFENSE_NAME  CMPLNT_NUM
#   524        46                             ARSON           9
#   525        46                           ASSAULT        2042
#   526        46                          BURGLARY         200
#   527        46           DRIVING_UNDER_INFLUENCE          27
#   528        46                           FORGERY         107
#   529        46                          GAMBLING           1
#   530        46                       HARRASSMENT        1814
#   531        46                          HOMICIDE         244
#   532        46                        KIDNAPPING           3
#   533        46                           LARCENY        1769
#   534        46                            MURDER           9
#   535        46     OFFENSES_AGAINST_PUBLIC_ORDER        1617
#   536        46  POSSESSION_CONTROLLED_SUBSSTANCE         604
#   537        46                 POSSESSION_WEAPON         113
#   538        46                           ROBBERY         358
#   539        46                        SEX_CRIMES         161
#   540        46             SOCIAL_RELATED_CRIMES          40
#   541        46                             THEFT         131
#   542        46            TRAFFIC_LAWS_VIOLATION         131
#   543        46                      UNCLASSIFIED          22),
#  (47,      DISTRICT                      OFFENSE_NAME  CMPLNT_NUM
#   544        47                             ARSON          23
#   545        47                           ASSAULT        2165
#   546        47                          BURGLARY         241
#   547        47           DRIVING_UNDER_INFLUENCE         153
#   548        47                           FORGERY         116
#   549        47                       HARRASSMENT        1654
#   550        47                          HOMICIDE         184
#   551        47                        KIDNAPPING           6
#   552        47                           LARCENY        1783
#   553        47                            MURDER           7
#   554        47     OFFENSES_AGAINST_PUBLIC_ORDER        1894
#   555        47  POSSESSION_CONTROLLED_SUBSSTANCE         238
#   556        47                 POSSESSION_WEAPON         156
#   557        47                           ROBBERY         345
#   558        47                        SEX_CRIMES         151
#   559        47             SOCIAL_RELATED_CRIMES          52
#   560        47                             THEFT         123
#   561        47            TRAFFIC_LAWS_VIOLATION         172
#   562        47                      UNCLASSIFIED          13),
#  (48,      DISTRICT                      OFFENSE_NAME  CMPLNT_NUM
#   563        48                             ARSON          21
#   564        48                           ASSAULT        1612
#   565        48                          BURGLARY         150
#   566        48           DRIVING_UNDER_INFLUENCE          23
#   567        48                           FORGERY          24
#   568        48                       HARRASSMENT        1214
#   569        48                          HOMICIDE         155
#   570        48                        KIDNAPPING           1
#   571        48                           LARCENY        1556
#   572        48                            MURDER          10
#   573        48     OFFENSES_AGAINST_PUBLIC_ORDER        1450
#   574        48  POSSESSION_CONTROLLED_SUBSSTANCE         269
#   575        48                 POSSESSION_WEAPON         143
#   576        48                           ROBBERY         309
#   577        48                        SEX_CRIMES         119
#   578        48             SOCIAL_RELATED_CRIMES          31
#   579        48                             THEFT          91
#   580        48            TRAFFIC_LAWS_VIOLATION         101
#   581        48                      UNCLASSIFIED          10),
#  (49,      DISTRICT                      OFFENSE_NAME  CMPLNT_NUM
#   582        49                             ARSON           9
#   583        49                           ASSAULT        1058
#   584        49                          BURGLARY         131
#   585        49           DRIVING_UNDER_INFLUENCE          53
#   586        49                           FORGERY          24
#   587        49                          GAMBLING           2
#   588        49                       HARRASSMENT         934
#   589        49                          HOMICIDE         202
#   590        49                           LARCENY        1489
#   591        49                            MURDER           3
#   592        49     OFFENSES_AGAINST_PUBLIC_ORDER        1215
#   593        49  POSSESSION_CONTROLLED_SUBSSTANCE         113
#   594        49                 POSSESSION_WEAPON          78
#   595        49                           ROBBERY         190
#   596        49                        SEX_CRIMES          85
#   597        49             SOCIAL_RELATED_CRIMES          29
#   598        49                             THEFT          61
#   599        49            TRAFFIC_LAWS_VIOLATION         361
#   600        49                      UNCLASSIFIED          34),
#  (50,      DISTRICT                      OFFENSE_NAME  CMPLNT_NUM
#   601        50                             ARSON           5
#   602        50                           ASSAULT         520
#   603        50                          BURGLARY         108
#   604        50           DRIVING_UNDER_INFLUENCE          17
#   605        50                           FORGERY          14
#   606        50                       HARRASSMENT         655
#   607        50                          HOMICIDE          45
#   608        50                           LARCENY        1557
#   609        50                            MURDER           1
#   610        50     OFFENSES_AGAINST_PUBLIC_ORDER         931
#   611        50  POSSESSION_CONTROLLED_SUBSSTANCE          54
#   612        50                 POSSESSION_WEAPON          16
#   613        50                           ROBBERY         106
#   614        50                        SEX_CRIMES          42
#   615        50             SOCIAL_RELATED_CRIMES          20
#   616        50                             THEFT          54
#   617        50            TRAFFIC_LAWS_VIOLATION          81
#   618        50                      UNCLASSIFIED           7),
#  (52,      DISTRICT                      OFFENSE_NAME  CMPLNT_NUM
#   619        52                             ARSON           8
#   620        52                           ASSAULT        1870
#   621        52                          BURGLARY         185
#   622        52           DRIVING_UNDER_INFLUENCE         118
#   623        52                           FORGERY          87
#   624        52                          GAMBLING           4
#   625        52                       HARRASSMENT        1322
#   626        52                          HOMICIDE         238
#   627        52                        KIDNAPPING           1
#   628        52                           LARCENY        2636
#   629        52                            MURDER           7
#   630        52     OFFENSES_AGAINST_PUBLIC_ORDER        1554
#   631        52  POSSESSION_CONTROLLED_SUBSSTANCE         649
#   632        52                 POSSESSION_WEAPON         216
#   633        52                           ROBBERY         361
#   634        52                        SEX_CRIMES         146
#   635        52             SOCIAL_RELATED_CRIMES          38
#   636        52                             THEFT         113
#   637        52            TRAFFIC_LAWS_VIOLATION         150
#   638        52                      UNCLASSIFIED          14),
#  (60,      DISTRICT                      OFFENSE_NAME  CMPLNT_NUM
#   639        60                             ARSON           9
#   640        60                           ASSAULT         920
#   641        60                          BURGLARY          86
#   642        60           DRIVING_UNDER_INFLUENCE          76
#   643        60                           FORGERY          58
#   644        60                          GAMBLING           2
#   645        60                       HARRASSMENT         842
#   646        60                          HOMICIDE         260
#   647        60                        KIDNAPPING           1
#   648        60                           LARCENY        1391
#   649        60                            MURDER           6
#   650        60     OFFENSES_AGAINST_PUBLIC_ORDER        1023
#   651        60  POSSESSION_CONTROLLED_SUBSSTANCE         239
#   652        60                 POSSESSION_WEAPON         140
#   653        60                           ROBBERY         122
#   654        60                        SEX_CRIMES         114
#   655        60             SOCIAL_RELATED_CRIMES           8
#   656        60                             THEFT         109
#   657        60            TRAFFIC_LAWS_VIOLATION          81
#   658        60                      UNCLASSIFIED          16),
#  (61,      DISTRICT                      OFFENSE_NAME  CMPLNT_NUM
#   659        61                             ARSON           3
#   660        61                           ASSAULT         719
#   661        61                          BURGLARY         149
#   662        61           DRIVING_UNDER_INFLUENCE          90
#   663        61                           FORGERY          52
#   664        61                          GAMBLING           1
#   665        61                       HARRASSMENT         610
#   666        61                          HOMICIDE         235
#   667        61                        KIDNAPPING           2
#   668        61                           LARCENY        1671
#   669        61                            MURDER           3
#   670        61     OFFENSES_AGAINST_PUBLIC_ORDER         838
#   671        61  POSSESSION_CONTROLLED_SUBSSTANCE          74
#   672        61                 POSSESSION_WEAPON          48
#   673        61                           ROBBERY         141
#   674        61                        SEX_CRIMES          85
#   675        61             SOCIAL_RELATED_CRIMES           7
#   676        61                             THEFT          98
#   677        61            TRAFFIC_LAWS_VIOLATION         142
#   678        61                      UNCLASSIFIED          10),
#  (62,      DISTRICT                      OFFENSE_NAME  CMPLNT_NUM
#   679        62                             ARSON           6
#   680        62                           ASSAULT         693
#   681        62                          BURGLARY         163
#   682        62           DRIVING_UNDER_INFLUENCE          60
#   683        62                           FORGERY          20
#   684        62                       HARRASSMENT         856
#   685        62                          HOMICIDE         212
#   686        62                        KIDNAPPING           1
#   687        62                           LARCENY        1825
#   688        62     OFFENSES_AGAINST_PUBLIC_ORDER         940
#   689        62  POSSESSION_CONTROLLED_SUBSSTANCE          96
#   690        62                 POSSESSION_WEAPON          28
#   691        62                           ROBBERY         132
#   692        62                        SEX_CRIMES          82
#   693        62             SOCIAL_RELATED_CRIMES          19
#   694        62                             THEFT          84
#   695        62            TRAFFIC_LAWS_VIOLATION          88
#   696        62                      UNCLASSIFIED           3),
#  (63,      DISTRICT                      OFFENSE_NAME  CMPLNT_NUM
#   697        63                             ARSON           6
#   698        63                           ASSAULT         501
#   699        63                          BURGLARY          90
#   700        63           DRIVING_UNDER_INFLUENCE          49
#   701        63                           FORGERY          63
#   702        63                       HARRASSMENT         572
#   703        63                          HOMICIDE         169
#   704        63                           LARCENY        1413
#   705        63                            MURDER           2
#   706        63     OFFENSES_AGAINST_PUBLIC_ORDER         633
#   707        63  POSSESSION_CONTROLLED_SUBSSTANCE          26
#   708        63                 POSSESSION_WEAPON          72
#   709        63                           ROBBERY          75
#   710        63                        SEX_CRIMES          74
#   711        63             SOCIAL_RELATED_CRIMES           9
#   712        63                             THEFT          69
#   713        63            TRAFFIC_LAWS_VIOLATION         116
#   714        63                      UNCLASSIFIED           2),
#  (66,      DISTRICT                      OFFENSE_NAME  CMPLNT_NUM
#   715        66                             ARSON           5
#   716        66                           ASSAULT         551
#   717        66                          BURGLARY         161
#   718        66           DRIVING_UNDER_INFLUENCE          64
#   719        66                           FORGERY          13
#   720        66                          GAMBLING           7
#   721        66                       HARRASSMENT         584
#   722        66                          HOMICIDE         143
#   723        66                        KIDNAPPING           1
#   724        66                           LARCENY        1394
#   725        66                            MURDER           1
#   726        66     OFFENSES_AGAINST_PUBLIC_ORDER         678
#   727        66  POSSESSION_CONTROLLED_SUBSSTANCE          39
#   728        66                 POSSESSION_WEAPON          12
#   729        66                           ROBBERY         116
#   730        66                        SEX_CRIMES          82
#   731        66             SOCIAL_RELATED_CRIMES           7
#   732        66                             THEFT          48
# ...
#   1214       106                      UNCLASSIFIED           6),
#  (107,       DISTRICT                      OFFENSE_NAME  CMPLNT_NUM
#   1215       107                             ARSON           6
#   1216       107                           ASSAULT         647
#   1217       107                          BURGLARY         223
#   1218       107           DRIVING_UNDER_INFLUENCE          45
#   1219       107                           FORGERY          25
#   1220       107                       HARRASSMENT         827
#   1221       107                          HOMICIDE         148
#   1222       107                           LARCENY        1368
#   1223       107                            MURDER           2
#   1224       107     OFFENSES_AGAINST_PUBLIC_ORDER        1068
#   1225       107  POSSESSION_CONTROLLED_SUBSSTANCE          38
#   1226       107                 POSSESSION_WEAPON          26
#   1227       107                           ROBBERY         158
#   1228       107                        SEX_CRIMES          86
#   1229       107             SOCIAL_RELATED_CRIMES          13
#   1230       107                             THEFT          90
#   1231       107            TRAFFIC_LAWS_VIOLATION         117
#   1232       107                      UNCLASSIFIED           1),
#  (108,       DISTRICT                      OFFENSE_NAME  CMPLNT_NUM
#   1233       108                             ARSON           4
#   1234       108                           ASSAULT         674
#   1235       108                          BURGLARY          94
#   1236       108           DRIVING_UNDER_INFLUENCE          73
#   1237       108                           FORGERY          67
#   1238       108                       HARRASSMENT         834
#   1239       108                          HOMICIDE         113
#   1240       108                        KIDNAPPING           2
#   1241       108                           LARCENY        1440
#   1242       108     OFFENSES_AGAINST_PUBLIC_ORDER         618
#   1243       108  POSSESSION_CONTROLLED_SUBSSTANCE          78
#   1244       108                 POSSESSION_WEAPON          17
#   1245       108                           ROBBERY         100
#   1246       108                        SEX_CRIMES          99
#   1247       108             SOCIAL_RELATED_CRIMES           9
#   1248       108                             THEFT         137
#   1249       108            TRAFFIC_LAWS_VIOLATION         119
#   1250       108                      UNCLASSIFIED           3),
#  (109,       DISTRICT                      OFFENSE_NAME  CMPLNT_NUM
#   1251       109                             ARSON           8
#   1252       109                           ASSAULT        1044
#   1253       109                          BURGLARY         360
#   1254       109           DRIVING_UNDER_INFLUENCE          68
#   1255       109                           FORGERY          57
#   1256       109                       HARRASSMENT        1395
#   1257       109                          HOMICIDE         264
#   1258       109                           LARCENY        3109
#   1259       109                            MURDER           3
#   1260       109     OFFENSES_AGAINST_PUBLIC_ORDER        1100
#   1261       109  POSSESSION_CONTROLLED_SUBSSTANCE         107
#   1262       109                 POSSESSION_WEAPON          49
#   1263       109                           ROBBERY         209
#   1264       109                        SEX_CRIMES         117
#   1265       109             SOCIAL_RELATED_CRIMES          23
#   1266       109                             THEFT         139
#   1267       109            TRAFFIC_LAWS_VIOLATION         172
#   1268       109                      UNCLASSIFIED           6),
#  (110,       DISTRICT                      OFFENSE_NAME  CMPLNT_NUM
#   1269       110                             ARSON           5
#   1270       110                           ASSAULT        1242
#   1271       110                          BURGLARY         126
#   1272       110           DRIVING_UNDER_INFLUENCE          50
#   1273       110                           FORGERY          51
#   1274       110                          GAMBLING           3
#   1275       110                       HARRASSMENT         975
#   1276       110                          HOMICIDE         152
#   1277       110                        KIDNAPPING           1
#   1278       110                           LARCENY        2401
#   1279       110                            MURDER           2
#   1280       110     OFFENSES_AGAINST_PUBLIC_ORDER         860
#   1281       110  POSSESSION_CONTROLLED_SUBSSTANCE          82
#   1282       110                 POSSESSION_WEAPON          40
#   1283       110                           ROBBERY         272
#   1284       110                        SEX_CRIMES         147
#   1285       110             SOCIAL_RELATED_CRIMES          12
#   1286       110                             THEFT          84
#   1287       110            TRAFFIC_LAWS_VIOLATION         125
#   1288       110                      UNCLASSIFIED           1),
#  (111,       DISTRICT                      OFFENSE_NAME  CMPLNT_NUM
#   1289       111                             ARSON           3
#   1290       111                           ASSAULT         277
#   1291       111                          BURGLARY         194
#   1292       111           DRIVING_UNDER_INFLUENCE          40
#   1293       111                           FORGERY          16
#   1294       111                       HARRASSMENT         431
#   1295       111                          HOMICIDE          76
#   1296       111                           LARCENY         835
#   1297       111     OFFENSES_AGAINST_PUBLIC_ORDER         396
#   1298       111  POSSESSION_CONTROLLED_SUBSSTANCE          29
#   1299       111                 POSSESSION_WEAPON          13
#   1300       111                           ROBBERY          25
#   1301       111                        SEX_CRIMES          38
#   1302       111             SOCIAL_RELATED_CRIMES           4
#   1303       111                             THEFT          83
#   1304       111            TRAFFIC_LAWS_VIOLATION          59
#   1305       111                      UNCLASSIFIED           1),
#  (112,       DISTRICT                      OFFENSE_NAME  CMPLNT_NUM
#   1306       112                             ARSON           3
#   1307       112                           ASSAULT         305
#   1308       112                          BURGLARY          51
#   1309       112           DRIVING_UNDER_INFLUENCE         104
#   1310       112                           FORGERY          13
#   1311       112                       HARRASSMENT         473
#   1312       112                          HOMICIDE          60
#   1313       112                           LARCENY        1336
#   1314       112     OFFENSES_AGAINST_PUBLIC_ORDER         501
#   1315       112  POSSESSION_CONTROLLED_SUBSSTANCE          14
#   1316       112                 POSSESSION_WEAPON          11
#   1317       112                           ROBBERY          40
#   1318       112                        SEX_CRIMES          63
#   1319       112             SOCIAL_RELATED_CRIMES           5
#   1320       112                             THEFT          74
#   1321       112            TRAFFIC_LAWS_VIOLATION          90
#   1322       112                      UNCLASSIFIED           4),
#  (113,       DISTRICT                      OFFENSE_NAME  CMPLNT_NUM
#   1323       113                             ARSON          14
#   1324       113                           ASSAULT        1334
#   1325       113                          BURGLARY         159
#   1326       113           DRIVING_UNDER_INFLUENCE          64
#   1327       113                           FORGERY         176
#   1328       113                       HARRASSMENT        1132
#   1329       113                          HOMICIDE         374
#   1330       113                        KIDNAPPING           1
#   1331       113                           LARCENY        1576
#   1332       113                            MURDER          14
#   1333       113     OFFENSES_AGAINST_PUBLIC_ORDER        1407
#   1334       113  POSSESSION_CONTROLLED_SUBSSTANCE         141
#   1335       113                 POSSESSION_WEAPON         240
#   1336       113                           ROBBERY         156
#   1337       113                        SEX_CRIMES         112
#   1338       113             SOCIAL_RELATED_CRIMES          34
#   1339       113                             THEFT         179
#   1340       113            TRAFFIC_LAWS_VIOLATION         218
#   1341       113                      UNCLASSIFIED          10),
#  (114,       DISTRICT                      OFFENSE_NAME  CMPLNT_NUM
#   1342       114                             ARSON           8
#   1343       114                           ASSAULT        1327
#   1344       114                          BURGLARY         202
#   1345       114           DRIVING_UNDER_INFLUENCE          86
#   1346       114                           FORGERY          60
#   1347       114                       HARRASSMENT        1251
#   1348       114                          HOMICIDE         362
#   1349       114                           LARCENY        2327
#   1350       114                            MURDER           1
#   1351       114     OFFENSES_AGAINST_PUBLIC_ORDER        1431
#   1352       114  POSSESSION_CONTROLLED_SUBSSTANCE         126
#   1353       114                 POSSESSION_WEAPON          88
#   1354       114                           ROBBERY         184
#   1355       114                        SEX_CRIMES         163
#   1356       114             SOCIAL_RELATED_CRIMES          20
#   1357       114                             THEFT         153
#   1358       114            TRAFFIC_LAWS_VIOLATION         201
#   1359       114                      UNCLASSIFIED          11),
#  (115,       DISTRICT                      OFFENSE_NAME  CMPLNT_NUM
#   1360       115                             ARSON          11
#   1361       115                           ASSAULT        1469
#   1362       115                          BURGLARY         131
#   1363       115           DRIVING_UNDER_INFLUENCE         123
#   1364       115                           FORGERY          90
#   1365       115                       HARRASSMENT        1067
#   1366       115                          HOMICIDE         283
#   1367       115                        KIDNAPPING          10
#   1368       115                           LARCENY        1801
#   1369       115                            MURDER          11
#   1370       115     OFFENSES_AGAINST_PUBLIC_ORDER        1079
#   1371       115  POSSESSION_CONTROLLED_SUBSSTANCE         150
#   1372       115                 POSSESSION_WEAPON         213
#   1373       115                           ROBBERY         245
#   1374       115                        SEX_CRIMES         237
#   1375       115             SOCIAL_RELATED_CRIMES          20
#   1376       115                             THEFT         151
#   1377       115            TRAFFIC_LAWS_VIOLATION         210
#   1378       115                      UNCLASSIFIED          12),
#  (120,       DISTRICT                      OFFENSE_NAME  CMPLNT_NUM
#   1379       120                             ARSON          15
#   1380       120                           ASSAULT        1103
#   1381       120                          BURGLARY          91
#   1382       120           DRIVING_UNDER_INFLUENCE         130
#   1383       120                           FORGERY          31
#   1384       120                          GAMBLING           1
#   1385       120                       HARRASSMENT        1485
#   1386       120                          HOMICIDE         362
#   1387       120                        KIDNAPPING           4
#   1388       120                           LARCENY        1129
#   1389       120                            MURDER           3
#   1390       120     OFFENSES_AGAINST_PUBLIC_ORDER        1567
#   1391       120  POSSESSION_CONTROLLED_SUBSSTANCE         243
#   1392       120                 POSSESSION_WEAPON         137
#   1393       120                           ROBBERY          94
#   1394       120                        SEX_CRIMES         104
#   1395       120             SOCIAL_RELATED_CRIMES          14
#   1396       120                             THEFT         117
#   1397       120            TRAFFIC_LAWS_VIOLATION          68
#   1398       120                      UNCLASSIFIED          17),
#  (121,       DISTRICT                      OFFENSE_NAME  CMPLNT_NUM
#   1399       121                             ARSON           5
#   1400       121                           ASSAULT         743
#   1401       121                          BURGLARY          95
#   1402       121           DRIVING_UNDER_INFLUENCE         293
#   1403       121                           FORGERY          21
#   1404       121                       HARRASSMENT        1033
#   1405       121                          HOMICIDE         224
#   1406       121                           LARCENY        1420
#   1407       121                            MURDER           2
#   1408       121     OFFENSES_AGAINST_PUBLIC_ORDER        1143
#   1409       121  POSSESSION_CONTROLLED_SUBSSTANCE          92
#   1410       121                 POSSESSION_WEAPON          51
#   1411       121                           ROBBERY          81
#   1412       121                        SEX_CRIMES          63
#   1413       121             SOCIAL_RELATED_CRIMES          26
#   1414       121                             THEFT         115
#   1415       121            TRAFFIC_LAWS_VIOLATION          68
#   1416       121                      UNCLASSIFIED          26),
#  (122,       DISTRICT                      OFFENSE_NAME  CMPLNT_NUM
#   1417       122                             ARSON           9
#   1418       122                           ASSAULT         487
#   1419       122                          BURGLARY          67
#   1420       122           DRIVING_UNDER_INFLUENCE         125
#   1421       122                           FORGERY          31
#   1422       122                       HARRASSMENT        1069
#   1423       122                          HOMICIDE         238
#   1424       122                           LARCENY         894
#   1425       122                            MURDER           6
#   1426       122     OFFENSES_AGAINST_PUBLIC_ORDER         839
#   1427       122  POSSESSION_CONTROLLED_SUBSSTANCE          98
#   1428       122                 POSSESSION_WEAPON          34
#   1429       122                           ROBBERY          40
#   1430       122                        SEX_CRIMES          56
#   1431       122             SOCIAL_RELATED_CRIMES           7
#   1432       122                             THEFT         141
#   1433       122            TRAFFIC_LAWS_VIOLATION          76
#   1434       122                      UNCLASSIFIED          23),
#  (123,       DISTRICT                      OFFENSE_NAME  CMPLNT_NUM
#   1435       123                             ARSON           3
#   1436       123                           ASSAULT         227
#   1437       123                          BURGLARY          32
#   1438       123           DRIVING_UNDER_INFLUENCE          96
#   1439       123                           FORGERY          11
#   1440       123                       HARRASSMENT         443
#   1441       123                          HOMICIDE          56
#   1442       123                           LARCENY         447
#   1443       123                            MURDER           3
#   1444       123     OFFENSES_AGAINST_PUBLIC_ORDER         514
#   1445       123  POSSESSION_CONTROLLED_SUBSSTANCE          54
#   1446       123                 POSSESSION_WEAPON          29
#   1447       123                           ROBBERY          12
#   1448       123                        SEX_CRIMES          21
#   1449       123             SOCIAL_RELATED_CRIMES           7
#   1450       123                             THEFT          74
#   1451       123            TRAFFIC_LAWS_VIOLATION          25
#   1452       123                      UNCLASSIFIED          16)]

# %%
# Using Lambda
# In a groupby you have a bunch of groups. `groupby.apply()` iterates through each group in a groupby and applies some function to it.

# Here, we are going to iterate through each DISTRICT group 
# and find the row in the "OFFENSE_NAME" column where the CMPLNT_NUM is the max 

# So this is like saying 
# result = precincts.apply(lambda group: column[row])
# where `column` is group.OFFENSE_NAME column 
# and `row` is the row index where CMPLNT_NUM is max

result = districts.apply(lambda group: group.OFFENSE_NAME[group.CMPLNT_NUM.idxmax()])

# %%
# Print most frequent crime in each precinct
result.to_frame()
# Out:
#                                       0
# DISTRICT
# 1                               LARCENY
# 5                               LARCENY
# 6                               LARCENY
# 7                               LARCENY
# 9                               LARCENY
# ...                                 ...
# 115                             LARCENY
# 120       OFFENSES_AGAINST_PUBLIC_ORDER
# 121                             LARCENY
# 122                         HARRASSMENT
# 123       OFFENSES_AGAINST_PUBLIC_ORDER
#
# [77 rows x 1 columns]

# %% [markdown]
# ### Make the chropleth map

# %% [markdown]
# ## Plot the frequency of top 10 crimes committed
# I want to see the nature of crimes being reported by plotting the top 10 most frequent crime reported.

# %%
# Get the top 10 crime types with high frequency
top_10_crimes = df.OFFENSE_NAME.value_counts().head(10)

# Sort in descending order
top_10_crimes= top_10_crimes[::-1]

# Plot using horizontal bar chart
ax = top_10_crimes.plot(kind='barh')
ax.set(xlabel= "Number of Crimes", ylabel="Crime")
# Out:
# [Text(0, 0.5, 'Crime'), Text(0.5, 0, 'Number of Crimes')]

# %% [markdown]
# There is a mix of violent and non violent crimes reported. Petit Larceny, Harrassment 3, 4, 5 and Assault are leading. Studies have shown that victims will most likely report a crime if it is violent and theft/larceny.

# %% [markdown]
# ## Make a bar graph of Felony vs Misdemeanor vs Violation
# I would like to see the offense level of crimes reported each month. I used unstacked bar graph to see the trends in each offense level.

# %%
# Plot the offense level occurence in each month
fig, ax = plt.subplots(figsize=(14,6))
crime_lvl = df[['MONTH','OFFENSE LEVEL']]
ax = sns.countplot(x="MONTH",
                   hue='OFFENSE LEVEL',
                   data=crime_lvl,
                   palette="PuBuGn_d")
plt.title('FELONY VS MISDEMEANOR VS VIOLATION')
# Out:
# Text(0.5, 1.0, 'FELONY VS MISDEMEANOR VS VIOLATION')

# %% [markdown]
# Looks like Misdemeanor is the top offense category of the crimes in NYC. This also makes sense considering Harrassment 3,4,5 is the most occuring crime type. This is better than having the majority of the crimes be felonies.
#
# You can see a general trend in the data, where as Misdeameanors increase and decrease, so do Felonies and Violations. This also relates back to the Time-Series plots we made for total crimes reported each month.

# %% [markdown]
# ## Make a Stacked Bar Graph of Top 5 Crimes in 2019
# I would like to see the distribution of crimes reported each month but due to various of crime being reported, it will be huge data to plot. We can cee this minute scale by plotting only the top 5 most crimes reported each month.

# %%
#Filter df only where rows are the top 10 crimes using .loc  
top_10_crimes = df.OFFENSE_NAME.value_counts().head(5).index.tolist()
df2 = df.loc[df['OFFENSE_NAME'].isin(top_10_crimes)]


df2 = df2.groupby(['MONTH', 'OFFENSE_NAME'])['MONTH'].count().unstack()
df2.head()
# Out:
# OFFENSE_NAME  ASSAULT  HARRASSMENT  HOMICIDE  LARCENY  \
# MONTH
# 1                5355         5433      1107    10138
# 2                4924         4952      1011     8942
# 3                5908         5761      1177     9930
# 4                5919         5952      1180    10281
# 5                7011         6456      1281    11214
#
# OFFENSE_NAME  OFFENSES_AGAINST_PUBLIC_ORDER
# MONTH
# 1                                      6692
# 2                                      5659
# 3                                      6653
# 4                                      6339
# 5                                      6888

# %%
# Plot Stacked Bar Graph
ax = df2.plot(kind='bar',legend="best", figsize=(18,8))
ax.set(xlabel="MONTH", ylabel="count")
# ax.legend(pos="center")
# Out:
# [Text(0, 0.5, 'count'), Text(0.5, 0, 'MONTH')]

# %% [markdown]
# ## Conclusion
#
# I used data compiled by the New York police department to extract some insights on crimes reported in New York Metropolitan Area. While the data analysis performed here is devoid of a national perspective my key findings can be distilled to a few key points below:
#
# - Brooklyn has the highest crime reported with 29% of total reports. That makes sense since Brooklyn is the most populated borough according to (https://guides.lib.jjay.cuny.edu/c.php?g=288385&p=1922495).
#
# - The trends of the crime reports in all boroughs are consistent throughout the year. All boroughs have the same months of high and low reports. No overlapping of data trends had occurred.
#
# - Brooklyn as being the one with the highest reports is also consistent to be the highest portion in overall's monthly total in 2019.
#
# - Interestingly, District 75 in Brooklyn as the highest district with most crimes reported followed by District 40, 44 and 52 which are in the Bronx. Manhattan has the second-highest reports overall.
#
# - All districts in NYC have crimes reported.
#
# - The top 10 most crimes reported include larceny, harassment, and assault.
#
# - The most frequent offense level of all crimes reported is a misdemeanor and the general trend of felonies and violations follows it throughout the whole year.
#
# - During hot weather, reports are more frequent compared to the cold season. Reports drop drastically as holidays approached.
#
# While these observations are illuminating, I should mention that they don't paint the whole picture and comparisons should be made with national or other comparable data including crime data from other cities to give more perspective. We don't know if the total crime reports are within the national average or too high. Such comparisons would help us build more compelling arguments in our data storytelling by using them to support our local findings.
#
# With that being said, our findings are still very relevant to the new detectives and residents of NYC for local decision making on how to lessen the crime reports in each borough.
