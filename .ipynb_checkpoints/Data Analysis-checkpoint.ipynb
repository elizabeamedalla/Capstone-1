# %% [markdown]
# # DATA WRANGLING: CRIME RATES IN NYC

# %% [markdown]
# ## Import packages and data

# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib as mpl
import seaborn as sns
sns.set_style("darkgrid")
sns.set(style="darkgrid", color_codes=True)
# df = pd.read_csv('./data/final_NYC_crimes.csv', parse_dates=[['DATE', 'TIME']])
df = pd.read_csv('./data/final_NYC_crimes.csv')

# %%
df['DATE'] = pd.to_datetime(df['DATE'])

# %% [markdown]
# # DATA STORYTELLING: CRIME RATES IN NYC

# %% [markdown]
# The purpose of this project is to be able to understand the nature of crimes that happen in NYC in each borough. Various crimes could be confined to different boroughs.
#
# I performed some data exploration and visualization in this notebook with the hope of uncovering some interesting insights along the way. I used publicly available data to explore crime in NYC from January 2019 to December 2019. The data is available from the NYC's data portal linked below.
#
# https://data.cityofnewyork.us/Public-Safety/NYPD-Complaint-Data-Current-Year-To-Date-/5uac-w243/data
#
# Though the original audience is the NYPD cops and detectives, the audience could be any New York City's resident with minimum knowledge of the technicalities of the code cells. There are comment in each cell codes to explain what steps I took to obtain the results.

# %% [markdown]
# ## Display amount of Crimes per borough in the data set

# %%
borough_count = df.BOROUGH.value_counts()
borough_count.plot(kind='pie', y = 'BOROUGH', shadow=False,autopct='%1.1f%%', legend = False)
borough_count
# Out:
# BROOKLYN         129370
# MANHATTAN        113650
# BRONX             99002
# QUEENS            90147
# STATEN ISLAND     18510
# UNKNOWN             299
# Name: BOROUGH, dtype: int64

# %% [markdown]
# We counted the ratio of crimes in each borough to the total crimes reported and did a pie plot. Brooklyn had the highest reported crimes but it was not too far of a difference from Manhattan, Bronx and Queens.

# %% [markdown]
# ## Plot frequency of crimes for each borough in 2019
# I want to see the trend of crimes reported every month in each borough. Is there peak season for crimes? When is the crime reported lowest? To see the bigger picture, I made time series plot for all the boroughs in each month.

# %%
# create subset df
boro_2019 = df[['MONTH', 'DAY', 'BOROUGH']]
boro_2019 = boro_2019[boro_2019.BOROUGH != 'UNKNOWN']
boro_2019
# Out:
#         MONTH  DAY        BOROUGH
# 0           1    1         QUEENS
# 1           1    1          BRONX
# 2           1    1       BROOKLYN
# 3           1    1          BRONX
# 4           1    1      MANHATTAN
# ...       ...  ...            ...
# 450973     12   31       BROOKLYN
# 450974     12   31          BRONX
# 450975     12   31       BROOKLYN
# 450976     12   31  STATEN ISLAND
# 450977     12   31          BRONX
#
# [450679 rows x 3 columns]

# %%
day_boro = boro_2019.groupby(['DAY','BOROUGH'])
day_boro = day_boro["DAY"].count().unstack()
day_boro
# Out:
# BOROUGH  BRONX  BROOKLYN  MANHATTAN  QUEENS  STATEN ISLAND
# DAY
# 1         3582      5090       4317    3537            844
# 2         3271      4339       3635    2938            627
# 3         3119      4364       3631    2959            633
# 4         3331      4257       3771    2929            603
# 5         3223      4354       3751    2964            634
# 6         3217      4195       3658    2916            652
# 7         3380      4084       3821    2873            595
# 8         3363      4355       3755    3025            612
# 9         3162      4117       3589    3006            579
# 10        3393      4323       3843    2921            643
# 11        3347      4361       3789    2989            618
# 12        3325      4258       3838    2878            548
# 13        3227      4188       3698    2914            587
# 14        3312      4212       3798    2953            555
# 15        3378      4484       3894    3141            646
# 16        3239      4347       3710    2999            605
# 17        3335      4320       3631    2859            610
# 18        3132      4163       3647    2961            642
# 19        3176      4269       3810    2888            608
# 20        3255      4257       3686    2969            590
# 21        3200      4113       3811    2877            576
# 22        3186      4283       3667    2869            655
# 23        3201      4210       3878    3023            639
# 24        3275      4148       3760    2963            547
# 25        3190      4090       3635    3001            584
# 26        3338      4135       3731    2910            616
# 27        3147      4146       3611    2916            592
# 28        3182      4190       3536    2908            543
# 29        2944      3683       3250    2678            517
# 30        2819      3702       3407    2750            501
# 31        1753      2333       2092    1633            309

# %% [markdown]
# ### Plot the frequency of crimes reported in all boroughs in one graph.

# %%
# use unstack() to create the dataframe of crimes for each borough per month
#Grouping
month_boro = boro_2019.groupby(['MONTH','BOROUGH'])
crimes_per_borough = month_boro["MONTH"].count().unstack()
crimes_per_borough
# Out:
# BOROUGH  BRONX  BROOKLYN  MANHATTAN  QUEENS  STATEN ISLAND
# MONTH
# 1         7874     10600       8823    7016           1506
# 2         6956      9160       7889    6387           1355
# 3         7987     10500       8996    7308           1477
# 4         7979     10436       9228    7086           1499
# 5         8817     11516       9953    8046           1674
# 6         8477     11383      10163    7991           1665
# 7         9331     12108      10392    8461           1721
# 8         9017     11566      10292    8191           1548
# 9         8694     11499      10198    7767           1691
# 10        8507     11179      10136    7675           1635
# 11        7930     10101       9106    7400           1422
# 12        7433      9322       8474    6819           1317

# %%
# Plot the df
fig, ax = plt.subplots(figsize=(10,5))
crimes_per_borough.plot(ax=ax, title="Crimes per Borough each month", legend=False)
ax.set(xlabel="MONTHS", ylabel="# of Crimes")

# Customize Legend
ax.legend(loc='center', frameon=True, ncol=2)

# %%
# Plot the df
# fig, ax = plt.hist(figsize=(10,5))
# day_boro.plot(ax=ax, title="crimes per borough each day", legend=False)
# ax.set(xlabel="days", ylabel="# of Crimes")

# # Customize Legend
# ax.legend(loc='center', frameon=True, ncol=2)

# %% [markdown]
# The trends of crimes reported are similar and consistent throughout the year for each borough. Brooklyn has been consistently on top. For more details, I made the time series plots of each borough.

# %% [markdown]
# ### Plot time series of Bronx in 2019

# %%
#create subset df with only 2 columns
boro_2019 = df[['DATE', 'BOROUGH', 'MONTH']]

boro_2019 = boro_2019[boro_2019.BOROUGH != 'UNKNOWN']

#Create the filter
bronx = boro_2019[boro_2019['BOROUGH'] == 'BRONX']

# Count the sum of occurences for each date
bronx = bronx.DATE.value_counts()

# # # Use resample to organize it into monthly sums
bronx = bronx.resample(rule='M').apply('sum')

# # # Plot
bronx.plot(kind='line', title = "BRONX")

# %% [markdown]
# ### Plot Manhattan in 2019

# %%
manhattan = boro_2019[boro_2019['BOROUGH'] == 'BROOKLYN']
manhattan = manhattan.DATE.value_counts()
manhattan = manhattan.resample(rule='M').apply('sum')
manhattan.plot(kind='line', title="BROOKLYN")

# %% [markdown]
# ### Plot Manhattan in 2019

# %%
manhattan = boro_2019[boro_2019['BOROUGH'] == 'MANHATTAN']
manhattan = manhattan.DATE.value_counts()
manhattan = manhattan.resample(rule='M').apply('sum')
manhattan.plot(kind='line', title="MANHATTAN")

# %% [markdown]
# ### Plot Queens in 2019

# %%
queens = boro_2019[boro_2019['BOROUGH'] == 'QUEENS']
queens = queens.DATE.value_counts()
queens = queens.resample(rule='M').apply('sum')
queens.plot(kind='line', title="QUEENS")

# %% [markdown]
# ### Plot Staten Island in 2019

# %%
staten_island = boro_2019[boro_2019['BOROUGH'] == 'STATEN ISLAND']
staten_island = staten_island.DATE.value_counts()
staten_island = staten_island.resample(rule='M').apply('sum')
staten_island.plot(kind='line', title="STATEN ISLAND")

# %% [markdown]
# All boroughs have a noticeable drop rate in February. Summer seems to be the peak season for crimes, starting in May and the highest and dropping starts in August. The highest crime reported happened in July and lowest are February and December.

# %% [markdown]
# ## Get the frequency of top 10 districts with most crimes.
# NYC is one of the most densely populated cities in the US so no doubt, crimes are reported in all parts of NYC. Now that we have the crime data for each borough, I want to break it down and see the top 10 districts with the most crimes reported.

# %%
# TODO: create another column where district and borough are combined in one column
district_borough = df[["DISTRICT", "BOROUGH"]].copy()
district_borough['DISTRICT_BOROUGH'] = df.apply(lambda x: f"{x['DISTRICT']}, {x['BOROUGH']}", axis=1)
district_borough

# Get the top 10 districts with highest frequencies of crimes reported
district_crimes = district_borough.DISTRICT_BOROUGH.value_counts().head(10)

#Sort in descending order
district_crimes = district_crimes.sort_values(ascending=True)
district_crimes
# Out:
# 67, BROOKLYN      8593
# 73, BROOKLYN      9010
# 43, BRONX         9309
# 46, BRONX         9393
# 47, BRONX         9468
# 14, MANHATTAN     9547
# 52, BRONX         9710
# 44, BRONX        11440
# 40, BRONX        12813
# 75, BROOKLYN     13936
# Name: DISTRICT_BOROUGH, dtype: int64

# %%
# Plot Crimes per District using horizontal bar chart
ax = district_crimes.plot(kind='barh', title="Crimes per District")
ax.set(xlabel="Number of Crimes", ylabel="District")
# Out:
# [Text(0, 0.5, 'District'), Text(0.5, 0, 'Number of Crimes')]

# %% [markdown]
# ## Make a Map of Total Crimes per District in 2019
# To visualize the crime data per district, we can use `sns.lmplot` to make the scatter plot of crimes reported per district. Just to clarify, this is not the exact map of NYC. This is a scatter plot based on the exact location of the occurence of the crime reported per X and Y coordinate of the crime data. There might be parts of NYC that is not dotted here since no crime was reported.

# %%
df_coord = df.loc[(df['X_COORD_CD']!=0)]

sns.lmplot('X_COORD_CD',
           'Y_COORD_CD',
           data=df_coord,
           fit_reg=False, 
           hue="DISTRICT", 
           palette='Dark2',
           height=12,
           ci=2,
           legend=False,
           scatter_kws={"marker": "D", 
                        "s": 10}) 
ax = plt.gca()
ax.set_title("ALL CRIMES REPORTED PER DISTRICT 2019")
# Out:
# Text(0.5, 1, 'ALL CRIMES REPORTED PER DISTRICT 2019')

# %% [markdown]
# ## Scatter plot for top 10 crimes

# %%
col2 = ['DATE','CRIME_TYPE','X_COORD_CD','Y_COORD_CD']
multiple_crimes = df[col2]
multiple_crimes = multiple_crimes[multiple_crimes['CRIME_TYPE']\
                  .isin(['LARCENY','OFFENSES_AGAINST_PUBLIC_ORDER','ASSAULT','HARRASSMENT', 'HOMICIDE', 'POSSESSION_CONTROLLED_SUBSSTANCE', 'ROBBERY', 'BURGLARY', 'TRAFFIC_LAWS_VIOLATION', 'SEX_CRIMES' ])]

# clean some rouge (0,0) coordinates
multiple_crimes = multiple_crimes[multiple_crimes['X_COORD_CD']!=0]


multiple_crimes.head()
# Out:
#         DATE                     CRIME_TYPE  X_COORD_CD  Y_COORD_CD
# 0 2019-01-01                    HARRASSMENT     1056264      205572
# 1 2019-01-01  OFFENSES_AGAINST_PUBLIC_ORDER     1004749      240880
# 2 2019-01-01                        LARCENY      990026      189746
# 3 2019-01-01  OFFENSES_AGAINST_PUBLIC_ORDER     1004749      240880
# 4 2019-01-01                        ASSAULT      987374      217550

# %%
g = sns.lmplot(x="X_COORD_CD",
               y="Y_COORD_CD",
               col="CRIME_TYPE",
               data=multiple_crimes.dropna(), 
               col_wrap=2, size=6, fit_reg=False, 
               sharey=False,
               scatter_kws={"marker": "D",
                            "s": 10})
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/seaborn/regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## Make a map of the most frequent crime in each district

# %%
# Implementing first solution from http://stackoverflow.com/questions/45161355/pandas-dataframe-find-the-max-after-groupby-two-columns-and-gaet-counts
# Make a groupby using DISTRICT and OFFENSE_NAME Column. 
# Set `as_index=False` so that the index is int and not the DISTRICT column. 
# `as_index=False` is what separates the groupby into individual rows. Try making it True.
# We want it as individual rows because of how we will use that shape to determine the most frequent crime in each District.
top_crime_in_districts = df.groupby(['DISTRICT', 'CRIME_TYPE'], as_index=False)['CMPLNT_NUM'].count()
top_crime_in_districts
# Out:
#       DISTRICT               CRIME_TYPE  CMPLNT_NUM
# 0            1                    ARSON           1
# 1            1                  ASSAULT         541
# 2            1                 BURGLARY         177
# 3            1  DRIVING_UNDER_INFLUENCE          16
# 4            1                    FRAUD         249
# ...        ...                      ...         ...
# 1439       123                  ROBBERY          12
# 1440       123               SEX_CRIMES          21
# 1441       123                    THEFT          11
# 1442       123   TRAFFIC_LAWS_VIOLATION          18
# 1443       123             UNCLASSIFIED          23
#
# [1444 rows x 3 columns]

# %%
# Create a second groupby of the previous groupby.
# This groupby uses only the DISTRICT column. 
# This will create groups for each District 1-123. 
districts = top_crime_in_districts.groupby('DISTRICT')
list(districts)
# Out:
# [(1,     DISTRICT                        CRIME_TYPE  CMPLNT_NUM
#   0          1                             ARSON           1
#   1          1                           ASSAULT         541
#   2          1                          BURGLARY         177
#   3          1           DRIVING_UNDER_INFLUENCE          16
#   4          1                             FRAUD         249
#   5          1                       HARRASSMENT         747
#   6          1                           LARCENY        3316
#   7          1                    MISC_PENAL_LAW          70
#   8          1                            MURDER           1
#   9          1     OFFENSES_AGAINST_PUBLIC_ORDER         911
#   10         1  POSSESSION_CONTROLLED_SUBSSTANCE          40
#   11         1                 POSSESSION_WEAPON          31
#   12         1                           ROBBERY          78
#   13         1                        SEX_CRIMES          99
#   14         1             SOCIAL_RELATED_CRIMES           1
#   15         1                             THEFT         136
#   16         1            TRAFFIC_LAWS_VIOLATION          62
#   17         1                      UNCLASSIFIED          10),
#  (5,     DISTRICT                        CRIME_TYPE  CMPLNT_NUM
#   18         5                             ARSON           9
#   19         5                           ASSAULT         799
#   20         5                          BURGLARY         138
#   21         5           DRIVING_UNDER_INFLUENCE          17
#   22         5                             FRAUD         172
#   23         5                       HARRASSMENT         632
#   24         5                           LARCENY        1562
#   25         5                    MISC_PENAL_LAW          87
#   26         5                            MURDER           4
#   27         5     OFFENSES_AGAINST_PUBLIC_ORDER         587
#   28         5  POSSESSION_CONTROLLED_SUBSSTANCE         112
#   29         5                 POSSESSION_WEAPON          27
#   30         5                           ROBBERY          91
#   31         5                        SEX_CRIMES         106
#   32         5             SOCIAL_RELATED_CRIMES           1
#   33         5                             THEFT          37
#   34         5            TRAFFIC_LAWS_VIOLATION          57
#   35         5                      UNCLASSIFIED         143),
#  (6,     DISTRICT                        CRIME_TYPE  CMPLNT_NUM
#   36         6                           ASSAULT         550
#   37         6                          BURGLARY         207
#   38         6           DRIVING_UNDER_INFLUENCE          26
#   39         6                             FRAUD         132
#   40         6                       HARRASSMENT         488
#   41         6                        KIDNAPPING           1
#   42         6                           LARCENY        2382
#   43         6                    MISC_PENAL_LAW          84
#   44         6     OFFENSES_AGAINST_PUBLIC_ORDER         574
#   45         6  POSSESSION_CONTROLLED_SUBSSTANCE         295
#   46         6                 POSSESSION_WEAPON          48
#   47         6                           ROBBERY         142
#   48         6                        SEX_CRIMES          64
#   49         6             SOCIAL_RELATED_CRIMES           2
#   50         6                             THEFT          42
#   51         6            TRAFFIC_LAWS_VIOLATION          36
#   52         6                      UNCLASSIFIED           1),
#  (7,     DISTRICT                        CRIME_TYPE  CMPLNT_NUM
#   53         7                             ARSON           5
#   54         7                           ASSAULT         752
#   55         7                          BURGLARY         154
#   56         7           DRIVING_UNDER_INFLUENCE          28
#   57         7                             FRAUD         103
#   58         7                       HARRASSMENT         598
#   59         7                        KIDNAPPING           2
#   60         7                           LARCENY        1248
#   61         7                    MISC_PENAL_LAW          67
#   62         7     OFFENSES_AGAINST_PUBLIC_ORDER         714
#   63         7  POSSESSION_CONTROLLED_SUBSSTANCE          71
#   64         7                 POSSESSION_WEAPON          61
#   65         7                           ROBBERY         149
#   66         7                        SEX_CRIMES          56
#   67         7                             THEFT          46
#   68         7            TRAFFIC_LAWS_VIOLATION          51
#   69         7                      UNCLASSIFIED           9),
#  (9,     DISTRICT                        CRIME_TYPE  CMPLNT_NUM
#   70         9                             ARSON           7
#   71         9                           ASSAULT         670
#   72         9                          BURGLARY         174
#   73         9           DRIVING_UNDER_INFLUENCE           8
#   74         9                             FRAUD         100
#   75         9                       HARRASSMENT         614
#   76         9                           LARCENY        2057
#   77         9                    MISC_PENAL_LAW          85
#   78         9                            MURDER           3
#   79         9     OFFENSES_AGAINST_PUBLIC_ORDER         611
#   80         9  POSSESSION_CONTROLLED_SUBSSTANCE         163
#   81         9                 POSSESSION_WEAPON          49
#   82         9                           ROBBERY         119
#   83         9                        SEX_CRIMES          80
#   84         9                             THEFT          21
#   85         9            TRAFFIC_LAWS_VIOLATION          46
#   86         9                      UNCLASSIFIED          11),
#  (10,      DISTRICT                        CRIME_TYPE  CMPLNT_NUM
#   87         10                             ARSON           2
#   88         10                           ASSAULT         493
#   89         10                          BURGLARY         131
#   90         10           DRIVING_UNDER_INFLUENCE          78
#   91         10                             FRAUD          83
#   92         10                       HARRASSMENT         541
#   93         10                        KIDNAPPING           1
#   94         10                           LARCENY        1621
#   95         10                    MISC_PENAL_LAW          59
#   96         10     OFFENSES_AGAINST_PUBLIC_ORDER         565
#   97         10  POSSESSION_CONTROLLED_SUBSSTANCE          97
#   98         10                 POSSESSION_WEAPON          51
#   99         10                           ROBBERY         122
#   100        10                        SEX_CRIMES          72
#   101        10             SOCIAL_RELATED_CRIMES           1
#   102        10                             THEFT          17
#   103        10            TRAFFIC_LAWS_VIOLATION          51
#   104        10                      UNCLASSIFIED           7),
#  (13,      DISTRICT                        CRIME_TYPE  CMPLNT_NUM
#   105        13                             ARSON           4
#   106        13                           ASSAULT         777
#   107        13                          BURGLARY         250
#   108        13           DRIVING_UNDER_INFLUENCE          35
#   109        13                             FRAUD         181
#   110        13                       HARRASSMENT         858
#   111        13                        KIDNAPPING           1
#   112        13                           LARCENY        3778
#   113        13                    MISC_PENAL_LAW         103
#   114        13     OFFENSES_AGAINST_PUBLIC_ORDER         869
#   115        13  POSSESSION_CONTROLLED_SUBSSTANCE         178
#   116        13                 POSSESSION_WEAPON          51
#   117        13                           ROBBERY         166
#   118        13                        SEX_CRIMES         160
#   119        13             SOCIAL_RELATED_CRIMES           1
#   120        13                             THEFT          59
#   121        13            TRAFFIC_LAWS_VIOLATION          73
#   122        13                      UNCLASSIFIED          12),
#  (14,      DISTRICT                        CRIME_TYPE  CMPLNT_NUM
#   123        14                             ARSON           4
#   124        14                           ASSAULT         960
#   125        14                          BURGLARY         234
#   126        14           DRIVING_UNDER_INFLUENCE          28
#   127        14                             FRAUD         337
#   128        14                          GAMBLING           1
#   129        14                       HARRASSMENT         816
#   130        14                        KIDNAPPING           2
#   131        14                           LARCENY        4963
#   132        14                    MISC_PENAL_LAW         106
#   133        14     OFFENSES_AGAINST_PUBLIC_ORDER        1004
#   134        14  POSSESSION_CONTROLLED_SUBSSTANCE         406
#   135        14                 POSSESSION_WEAPON          79
#   136        14                           ROBBERY         137
#   137        14                        SEX_CRIMES         231
#   138        14             SOCIAL_RELATED_CRIMES           3
#   139        14                             THEFT         157
#   140        14            TRAFFIC_LAWS_VIOLATION          73
#   141        14                      UNCLASSIFIED           6),
#  (17,      DISTRICT                        CRIME_TYPE  CMPLNT_NUM
#   142        17                             ARSON           1
#   143        17                           ASSAULT         365
#   144        17                          BURGLARY         121
#   145        17           DRIVING_UNDER_INFLUENCE          13
#   146        17                             FRAUD         135
#   147        17                       HARRASSMENT         485
#   148        17                        KIDNAPPING           1
#   149        17                           LARCENY        1869
#   150        17                    MISC_PENAL_LAW          39
#   151        17     OFFENSES_AGAINST_PUBLIC_ORDER         350
#   152        17  POSSESSION_CONTROLLED_SUBSSTANCE          44
#   153        17                 POSSESSION_WEAPON          13
#   154        17                           ROBBERY          59
#   155        17                        SEX_CRIMES          64
#   156        17             SOCIAL_RELATED_CRIMES           1
#   157        17                             THEFT          31
#   158        17            TRAFFIC_LAWS_VIOLATION          84
#   159        17                      UNCLASSIFIED           2),
#  (18,      DISTRICT                        CRIME_TYPE  CMPLNT_NUM
#   160        18                             ARSON           4
#   161        18                           ASSAULT         903
#   162        18                          BURGLARY         209
#   163        18           DRIVING_UNDER_INFLUENCE          25
#   164        18                             FRAUD         265
#   165        18                       HARRASSMENT        1057
#   166        18                           LARCENY        3926
#   167        18                    MISC_PENAL_LAW          66
#   168        18                            MURDER           1
#   169        18     OFFENSES_AGAINST_PUBLIC_ORDER         835
#   170        18  POSSESSION_CONTROLLED_SUBSSTANCE          77
#   171        18                 POSSESSION_WEAPON          44
#   172        18                           ROBBERY         172
#   173        18                        SEX_CRIMES         158
#   174        18             SOCIAL_RELATED_CRIMES           1
#   175        18                             THEFT          74
#   176        18            TRAFFIC_LAWS_VIOLATION          96
#   177        18                      UNCLASSIFIED           5),
#  (19,      DISTRICT                        CRIME_TYPE  CMPLNT_NUM
#   178        19                             ARSON           7
#   179        19                           ASSAULT         578
#   180        19                          BURGLARY         251
#   181        19           DRIVING_UNDER_INFLUENCE          16
#   182        19                             FRAUD         355
#   183        19                       HARRASSMENT         829
#   184        19                        KIDNAPPING           1
#   185        19                           LARCENY        4200
#   186        19                    MISC_PENAL_LAW         125
#   187        19     OFFENSES_AGAINST_PUBLIC_ORDER         693
#   188        19  POSSESSION_CONTROLLED_SUBSSTANCE          26
#   189        19                 POSSESSION_WEAPON          41
#   190        19                           ROBBERY         170
#   191        19                        SEX_CRIMES         108
#   192        19             SOCIAL_RELATED_CRIMES           1
#   193        19                             THEFT          40
#   194        19            TRAFFIC_LAWS_VIOLATION          86
#   195        19                      UNCLASSIFIED          14),
#  (20,      DISTRICT                        CRIME_TYPE  CMPLNT_NUM
#   196        20                             ARSON           2
#   197        20                           ASSAULT         337
#   198        20                          BURGLARY          92
#   199        20           DRIVING_UNDER_INFLUENCE          13
#   200        20                             FRAUD         126
#   201        20                       HARRASSMENT         536
#   202        20                           LARCENY        2166
#   203        20                    MISC_PENAL_LAW          45
#   204        20                            MURDER           1
#   205        20     OFFENSES_AGAINST_PUBLIC_ORDER         510
#   206        20  POSSESSION_CONTROLLED_SUBSSTANCE          20
#   207        20                 POSSESSION_WEAPON          20
#   208        20                           ROBBERY          85
#   209        20                        SEX_CRIMES          76
#   210        20             SOCIAL_RELATED_CRIMES           2
#   211        20                             THEFT          20
#   212        20            TRAFFIC_LAWS_VIOLATION          29
#   213        20                      UNCLASSIFIED           8),
#  (22,      DISTRICT                        CRIME_TYPE  CMPLNT_NUM
#   214        22                             ARSON           1
#   215        22                           ASSAULT          42
#   216        22                          BURGLARY           1
#   217        22           DRIVING_UNDER_INFLUENCE           1
#   218        22                             FRAUD           2
#   219        22                       HARRASSMENT          34
#   220        22                           LARCENY          88
#   221        22                    MISC_PENAL_LAW           2
#   222        22                            MURDER           1
#   223        22     OFFENSES_AGAINST_PUBLIC_ORDER          34
#   224        22  POSSESSION_CONTROLLED_SUBSSTANCE          11
#   225        22                 POSSESSION_WEAPON           2
#   226        22                           ROBBERY          21
#   227        22                        SEX_CRIMES           8
#   228        22                             THEFT           1
#   229        22            TRAFFIC_LAWS_VIOLATION           1),
#  (23,      DISTRICT                        CRIME_TYPE  CMPLNT_NUM
#   230        23                             ARSON          17
#   231        23                           ASSAULT        1104
#   232        23                          BURGLARY         145
#   233        23           DRIVING_UNDER_INFLUENCE          24
#   234        23                             FRAUD         133
#   235        23                          GAMBLING          13
#   236        23                       HARRASSMENT         923
#   237        23                        KIDNAPPING           1
#   238        23                           LARCENY        1119
#   239        23                    MISC_PENAL_LAW         161
#   240        23                            MURDER           2
#   241        23     OFFENSES_AGAINST_PUBLIC_ORDER        1105
#   242        23  POSSESSION_CONTROLLED_SUBSSTANCE         170
#   243        23                 POSSESSION_WEAPON         142
#   244        23                           ROBBERY         167
#   245        23                        SEX_CRIMES         108
#   246        23             SOCIAL_RELATED_CRIMES           5
#   247        23                             THEFT          43
#   248        23            TRAFFIC_LAWS_VIOLATION          59
#   249        23                      UNCLASSIFIED          12),
#  (24,      DISTRICT                        CRIME_TYPE  CMPLNT_NUM
#   250        24                             ARSON           5
#   251        24                           ASSAULT         519
#   252        24                          BURGLARY         125
#   253        24           DRIVING_UNDER_INFLUENCE          16
#   254        24                             FRAUD         115
#   255        24                          GAMBLING           9
#   256        24                       HARRASSMENT         607
#   257        24                        KIDNAPPING           2
#   258        24                           LARCENY        1986
#   259        24                    MISC_PENAL_LAW          78
#   260        24                            MURDER           2
#   261        24     OFFENSES_AGAINST_PUBLIC_ORDER         556
#   262        24  POSSESSION_CONTROLLED_SUBSSTANCE          39
#   263        24                 POSSESSION_WEAPON          33
#   264        24                           ROBBERY         172
#   265        24                        SEX_CRIMES          57
#   266        24             SOCIAL_RELATED_CRIMES           3
#   267        24                             THEFT          30
#   268        24            TRAFFIC_LAWS_VIOLATION          24
#   269        24                      UNCLASSIFIED           3),
#  (25,      DISTRICT                        CRIME_TYPE  CMPLNT_NUM
#   270        25                             ARSON           5
#   271        25                           ASSAULT        1128
#   272        25                          BURGLARY         138
#   273        25           DRIVING_UNDER_INFLUENCE          53
#   274        25                             FRAUD         182
#   275        25                          GAMBLING           5
#   276        25                       HARRASSMENT         810
#   277        25                        KIDNAPPING           3
#   278        25                           LARCENY        1753
#   279        25                    MISC_PENAL_LAW         200
#   280        25                            MURDER           3
#   281        25     OFFENSES_AGAINST_PUBLIC_ORDER        1080
#   282        25  POSSESSION_CONTROLLED_SUBSSTANCE        1094
#   283        25                 POSSESSION_WEAPON         151
#   284        25                           ROBBERY         172
#   285        25                        SEX_CRIMES         123
#   286        25             SOCIAL_RELATED_CRIMES           2
#   287        25                             THEFT          50
#   288        25            TRAFFIC_LAWS_VIOLATION          80
#   289        25                      UNCLASSIFIED          41),
#  (26,      DISTRICT                        CRIME_TYPE  CMPLNT_NUM
#   290        26                             ARSON           1
#   291        26                           ASSAULT         392
#   292        26                          BURGLARY         112
#   293        26           DRIVING_UNDER_INFLUENCE          13
#   294        26                             FRAUD         109
#   295        26                          GAMBLING           3
#   296        26                       HARRASSMENT         456
#   297        26                           LARCENY        1083
#   298        26                    MISC_PENAL_LAW          64
#   299        26                            MURDER           2
#   300        26     OFFENSES_AGAINST_PUBLIC_ORDER         686
#   301        26  POSSESSION_CONTROLLED_SUBSSTANCE          63
#   302        26                 POSSESSION_WEAPON          33
#   303        26                           ROBBERY         127
#   304        26                        SEX_CRIMES          47
#   305        26             SOCIAL_RELATED_CRIMES           2
#   306        26                             THEFT          28
#   307        26            TRAFFIC_LAWS_VIOLATION          20
#   308        26                      UNCLASSIFIED           6),
#  (28,      DISTRICT                        CRIME_TYPE  CMPLNT_NUM
#   309        28                             ARSON           7
#   310        28                           ASSAULT         885
#   311        28                          BURGLARY         128
#   312        28           DRIVING_UNDER_INFLUENCE          33
#   313        28                             FRAUD          95
#   314        28                          GAMBLING          30
#   315        28                       HARRASSMENT         732
#   316        28                        KIDNAPPING           2
#   317        28                           LARCENY        1548
#   318        28                    MISC_PENAL_LAW         130
#   319        28                            MURDER           5
#   320        28     OFFENSES_AGAINST_PUBLIC_ORDER         848
#   321        28  POSSESSION_CONTROLLED_SUBSSTANCE         220
#   322        28                 POSSESSION_WEAPON          65
#   323        28                           ROBBERY         163
#   324        28                        SEX_CRIMES          48
#   325        28             SOCIAL_RELATED_CRIMES           2
#   326        28                             THEFT          40
#   327        28            TRAFFIC_LAWS_VIOLATION          39
#   328        28                      UNCLASSIFIED          19),
#  (30,      DISTRICT                        CRIME_TYPE  CMPLNT_NUM
#   329        30                             ARSON           4
#   330        30                           ASSAULT         617
#   331        30                          BURGLARY          87
#   332        30           DRIVING_UNDER_INFLUENCE          60
#   333        30                             FRAUD          74
#   334        30                          GAMBLING           9
#   335        30                       HARRASSMENT         640
#   336        30                           LARCENY        1137
#   337        30                    MISC_PENAL_LAW          74
#   338        30                            MURDER           6
#   339        30     OFFENSES_AGAINST_PUBLIC_ORDER         625
#   340        30  POSSESSION_CONTROLLED_SUBSSTANCE          71
#   341        30                 POSSESSION_WEAPON          32
#   342        30                           ROBBERY         190
#   343        30                        SEX_CRIMES          66
#   344        30             SOCIAL_RELATED_CRIMES           1
#   345        30                             THEFT          18
#   346        30            TRAFFIC_LAWS_VIOLATION          38
#   347        30                      UNCLASSIFIED          14),
#  (32,      DISTRICT                        CRIME_TYPE  CMPLNT_NUM
#   348        32                             ARSON          16
#   349        32                           ASSAULT        1161
#   350        32                          BURGLARY         214
#   351        32           DRIVING_UNDER_INFLUENCE          49
#   352        32                             FRAUD         116
#   353        32                          GAMBLING           5
#   354        32                       HARRASSMENT        1041
#   355        32                           LARCENY        1096
#   356        32                    MISC_PENAL_LAW         194
#   357        32                            MURDER          10
#   358        32     OFFENSES_AGAINST_PUBLIC_ORDER        1077
#   359        32  POSSESSION_CONTROLLED_SUBSSTANCE         217
#   360        32                 POSSESSION_WEAPON         116
#   361        32                           ROBBERY         217
#   362        32                        SEX_CRIMES          99
#   363        32             SOCIAL_RELATED_CRIMES           6
#   364        32                             THEFT          37
#   365        32            TRAFFIC_LAWS_VIOLATION          55
#   366        32                      UNCLASSIFIED          30),
#  (33,      DISTRICT                        CRIME_TYPE  CMPLNT_NUM
#   367        33                             ARSON          11
#   368        33                           ASSAULT         640
#   369        33                          BURGLARY         139
#   370        33           DRIVING_UNDER_INFLUENCE          44
#   371        33                             FRAUD          95
#   372        33                          GAMBLING           1
#   373        33                       HARRASSMENT         593
#   374        33                        KIDNAPPING           5
#   375        33                           LARCENY        1075
#   376        33                    MISC_PENAL_LAW         133
#   377        33                            MURDER           4
#   378        33     OFFENSES_AGAINST_PUBLIC_ORDER         649
#   379        33  POSSESSION_CONTROLLED_SUBSSTANCE         255
#   380        33                 POSSESSION_WEAPON          42
#   381        33                           ROBBERY         144
#   382        33                        SEX_CRIMES          55
#   383        33             SOCIAL_RELATED_CRIMES           1
#   384        33                             THEFT          25
#   385        33            TRAFFIC_LAWS_VIOLATION          54
#   386        33                      UNCLASSIFIED          23),
#  (34,      DISTRICT                        CRIME_TYPE  CMPLNT_NUM
#   387        34                             ARSON           5
#   388        34                           ASSAULT         892
#   389        34                          BURGLARY         148
#   390        34           DRIVING_UNDER_INFLUENCE          93
#   391        34                             FRAUD         130
#   392        34                       HARRASSMENT         736
#   393        34                           LARCENY        1606
#   394        34                    MISC_PENAL_LAW         110
#   395        34                            MURDER           6
#   396        34     OFFENSES_AGAINST_PUBLIC_ORDER         842
#   397        34  POSSESSION_CONTROLLED_SUBSSTANCE         137
#   398        34                 POSSESSION_WEAPON         113
#   399        34                           ROBBERY         224
#   400        34                        SEX_CRIMES          81
#   401        34             SOCIAL_RELATED_CRIMES           2
#   402        34                             THEFT          40
#   403        34            TRAFFIC_LAWS_VIOLATION          86
#   404        34                      UNCLASSIFIED          14),
#  (40,      DISTRICT                        CRIME_TYPE  CMPLNT_NUM
#   405        40                             ARSON          34
#   406        40                           ASSAULT        2454
#   407        40                          BURGLARY         340
#   408        40           DRIVING_UNDER_INFLUENCE          70
#   409        40                             FRAUD         266
#   410        40                          GAMBLING          16
#   411        40                       HARRASSMENT        2003
#   412        40                           LARCENY        2555
#   413        40                    MISC_PENAL_LAW         242
#   414        40                            MURDER          10
#   415        40     OFFENSES_AGAINST_PUBLIC_ORDER        2161
#   416        40  POSSESSION_CONTROLLED_SUBSSTANCE        1487
#   417        40                 POSSESSION_WEAPON         241
#   418        40                           ROBBERY         471
#   419        40                        SEX_CRIMES         174
#   420        40             SOCIAL_RELATED_CRIMES           6
#   421        40                             THEFT          72
#   422        40            TRAFFIC_LAWS_VIOLATION         159
#   423        40                      UNCLASSIFIED          65),
#  (41,      DISTRICT                        CRIME_TYPE  CMPLNT_NUM
#   424        41                             ARSON          25
#   425        41                           ASSAULT         996
#   426        41                          BURGLARY         129
#   427        41           DRIVING_UNDER_INFLUENCE          32
#   428        41                             FRAUD          72
#   429        41                          GAMBLING          18
#   430        41                       HARRASSMENT         894
#   431        41                        KIDNAPPING           2
#   432        41                           LARCENY        1191
#   433        41                    MISC_PENAL_LAW         205
#   434        41                            MURDER           4
#   435        41     OFFENSES_AGAINST_PUBLIC_ORDER        1180
#   436        41  POSSESSION_CONTROLLED_SUBSSTANCE         204
#   437        41                 POSSESSION_WEAPON         109
#   438        41                           ROBBERY         165
#   439        41                        SEX_CRIMES         102
#   440        41             SOCIAL_RELATED_CRIMES          19
#   441        41                             THEFT          30
#   442        41            TRAFFIC_LAWS_VIOLATION          79
#   443        41                      UNCLASSIFIED          12),
#  (42,      DISTRICT                        CRIME_TYPE  CMPLNT_NUM
#   444        42                             ARSON          26
#   445        42                           ASSAULT        1753
#   446        42                          BURGLARY         236
#   447        42           DRIVING_UNDER_INFLUENCE          33
#   448        42                             FRAUD         149
#   449        42                          GAMBLING           6
#   450        42                       HARRASSMENT        1547
#   451        42                        KIDNAPPING           2
#   452        42                           LARCENY        1582
#   453        42                    MISC_PENAL_LAW         125
#   454        42                            MURDER          12
#   455        42     OFFENSES_AGAINST_PUBLIC_ORDER        1446
#   456        42  POSSESSION_CONTROLLED_SUBSSTANCE         308
#   457        42                 POSSESSION_WEAPON         169
#   458        42                           ROBBERY         285
#   459        42                        SEX_CRIMES         120
#   460        42             SOCIAL_RELATED_CRIMES           6
#   461        42                             THEFT          53
#   462        42            TRAFFIC_LAWS_VIOLATION         115
#   463        42                      UNCLASSIFIED          46),
#  (43,      DISTRICT                        CRIME_TYPE  CMPLNT_NUM
#   464        43                             ARSON          28
#   465        43                           ASSAULT        1977
#   466        43                          BURGLARY         192
#   467        43           DRIVING_UNDER_INFLUENCE          38
#   468        43                             FRAUD         137
#   469        43                          GAMBLING           1
#   470        43                       HARRASSMENT        1729
#   471        43                        KIDNAPPING           6
#   472        43                           LARCENY        2213
#   473        43                    MISC_PENAL_LAW         195
#   474        43                            MURDER           5
#   475        43     OFFENSES_AGAINST_PUBLIC_ORDER        1638
#   476        43  POSSESSION_CONTROLLED_SUBSSTANCE         227
#   477        43                 POSSESSION_WEAPON         157
#   478        43                           ROBBERY         357
#   479        43                        SEX_CRIMES         148
#   480        43             SOCIAL_RELATED_CRIMES           5
#   481        43                             THEFT          51
#   482        43            TRAFFIC_LAWS_VIOLATION         142
#   483        43                      UNCLASSIFIED          69),
#  (44,      DISTRICT                        CRIME_TYPE  CMPLNT_NUM
#   484        44                             ARSON          15
#   485        44                           ASSAULT        2492
#   486        44                          BURGLARY         249
#   487        44           DRIVING_UNDER_INFLUENCE          25
#   488        44                             FRAUD         353
#   489        44                          GAMBLING           1
#   490        44                       HARRASSMENT        1877
#   491        44                        KIDNAPPING           6
#   492        44                           LARCENY        2543
#   493        44                    MISC_PENAL_LAW         209
#   494        44                            MURDER           8
#   495        44     OFFENSES_AGAINST_PUBLIC_ORDER        2069
#   496        44  POSSESSION_CONTROLLED_SUBSSTANCE         404
#   497        44                 POSSESSION_WEAPON         254
#   498        44                           ROBBERY         427
#   499        44                        SEX_CRIMES         174
#   500        44             SOCIAL_RELATED_CRIMES           5
#   501        44                             THEFT          90
#   502        44            TRAFFIC_LAWS_VIOLATION         176
#   503        44                      UNCLASSIFIED          70),
#  (45,      DISTRICT                        CRIME_TYPE  CMPLNT_NUM
#   504        45                             ARSON           7
#   505        45                           ASSAULT         964
#   506        45                          BURGLARY         120
#   507        45           DRIVING_UNDER_INFLUENCE          86
#   508        45                             FRAUD          63
#   509        45                       HARRASSMENT        1109
#   510        45                        KIDNAPPING           3
#   511        45                           LARCENY        1812
#   512        45                    MISC_PENAL_LAW          84
#   513        45                            MURDER           3
#   514        45     OFFENSES_AGAINST_PUBLIC_ORDER        1109
#   515        45  POSSESSION_CONTROLLED_SUBSSTANCE          80
#   516        45                 POSSESSION_WEAPON          44
#   517        45                           ROBBERY         142
#   518        45                        SEX_CRIMES          61
#   519        45             SOCIAL_RELATED_CRIMES           1
#   520        45                             THEFT          32
#   521        45            TRAFFIC_LAWS_VIOLATION          75
#   522        45                      UNCLASSIFIED          14),
#  (46,      DISTRICT                        CRIME_TYPE  CMPLNT_NUM
#   523        46                             ARSON           9
#   524        46                           ASSAULT        2042
#   525        46                          BURGLARY         218
#   526        46           DRIVING_UNDER_INFLUENCE          27
#   527        46                             FRAUD         199
#   528        46                          GAMBLING           1
#   529        46                       HARRASSMENT        1794
#   530        46                        KIDNAPPING           3
#   531        46                           LARCENY        1769
#   532        46                    MISC_PENAL_LAW         244
#   533        46                            MURDER           9
#   534        46     OFFENSES_AGAINST_PUBLIC_ORDER        1597
#   535        46  POSSESSION_CONTROLLED_SUBSSTANCE         604
#   536        46                 POSSESSION_WEAPON         123
#   537        46                           ROBBERY         358
#   538        46                        SEX_CRIMES         161
#   539        46             SOCIAL_RELATED_CRIMES           9
#   540        46                             THEFT          59
#   541        46            TRAFFIC_LAWS_VIOLATION         121
#   542        46                      UNCLASSIFIED          55),
#  (47,      DISTRICT                        CRIME_TYPE  CMPLNT_NUM
#   543        47                             ARSON          23
#   544        47                           ASSAULT        2165
#   545        47                          BURGLARY         304
#   546        47           DRIVING_UNDER_INFLUENCE         153
#   547        47                             FRAUD         193
#   548        47                       HARRASSMENT        1654
#   549        47                        KIDNAPPING           6
#   550        47                           LARCENY        1783
#   551        47                    MISC_PENAL_LAW         184
#   552        47                            MURDER           7
#   553        47     OFFENSES_AGAINST_PUBLIC_ORDER        1831
#   554        47  POSSESSION_CONTROLLED_SUBSSTANCE         238
#   555        47                 POSSESSION_WEAPON         176
#   556        47                           ROBBERY         345
#   557        47                        SEX_CRIMES         151
#   558        47             SOCIAL_RELATED_CRIMES           6
#   559        47                             THEFT          46
#   560        47            TRAFFIC_LAWS_VIOLATION         152
#   561        47                      UNCLASSIFIED          59),
#  (48,      DISTRICT                        CRIME_TYPE  CMPLNT_NUM
#   562        48                             ARSON          21
#   563        48                           ASSAULT        1612
#   564        48                          BURGLARY         183
#   565        48           DRIVING_UNDER_INFLUENCE          23
#   566        48                             FRAUD          75
#   567        48                       HARRASSMENT        1214
#   568        48                        KIDNAPPING           1
#   569        48                           LARCENY        1556
#   570        48                    MISC_PENAL_LAW         154
#   571        48                            MURDER          11
#   572        48     OFFENSES_AGAINST_PUBLIC_ORDER        1417
#   573        48  POSSESSION_CONTROLLED_SUBSSTANCE         269
#   574        48                 POSSESSION_WEAPON         161
#   575        48                           ROBBERY         309
#   576        48                        SEX_CRIMES         119
#   577        48             SOCIAL_RELATED_CRIMES           4
#   578        48                             THEFT          40
#   579        48            TRAFFIC_LAWS_VIOLATION          83
#   580        48                      UNCLASSIFIED          37),
#  (49,      DISTRICT                        CRIME_TYPE  CMPLNT_NUM
#   581        49                             ARSON           9
#   582        49                           ASSAULT        1058
#   583        49                          BURGLARY         160
#   584        49           DRIVING_UNDER_INFLUENCE          53
#   585        49                             FRAUD          58
#   586        49                          GAMBLING           2
#   587        49                       HARRASSMENT         934
#   588        49                           LARCENY        1489
#   589        49                    MISC_PENAL_LAW         202
#   590        49                            MURDER           3
#   591        49     OFFENSES_AGAINST_PUBLIC_ORDER        1186
#   592        49  POSSESSION_CONTROLLED_SUBSSTANCE         113
#   593        49                 POSSESSION_WEAPON          98
#   594        49                           ROBBERY         190
#   595        49                        SEX_CRIMES          85
#   596        49             SOCIAL_RELATED_CRIMES           1
#   597        49                             THEFT          27
#   598        49            TRAFFIC_LAWS_VIOLATION         341
#   599        49                      UNCLASSIFIED          62),
#  (50,      DISTRICT                        CRIME_TYPE  CMPLNT_NUM
#   600        50                             ARSON           5
#   601        50                           ASSAULT         520
#   602        50                          BURGLARY         120
#   603        50           DRIVING_UNDER_INFLUENCE          17
#   604        50                             FRAUD          46
#   605        50                       HARRASSMENT         655
#   606        50                           LARCENY        1557
#   607        50                    MISC_PENAL_LAW          45
#   608        50                            MURDER           1
#   609        50     OFFENSES_AGAINST_PUBLIC_ORDER         919
#   610        50  POSSESSION_CONTROLLED_SUBSSTANCE          54
#   611        50                 POSSESSION_WEAPON          37
#   612        50                           ROBBERY         106
#   613        50                        SEX_CRIMES          42
#   614        50             SOCIAL_RELATED_CRIMES           2
#   615        50                             THEFT          22
#   616        50            TRAFFIC_LAWS_VIOLATION          60
#   617        50                      UNCLASSIFIED          25),
#  (52,      DISTRICT                        CRIME_TYPE  CMPLNT_NUM
#   618        52                             ARSON           8
#   619        52                           ASSAULT        1870
#   620        52                          BURGLARY         204
#   621        52           DRIVING_UNDER_INFLUENCE         118
#   622        52                             FRAUD         151
#   623        52                          GAMBLING           4
#   624        52                       HARRASSMENT        1321
#   625        52                        KIDNAPPING           1
#   626        52                           LARCENY        2636
#   627        52                    MISC_PENAL_LAW         235
#   628        52                            MURDER          10
#   629        52     OFFENSES_AGAINST_PUBLIC_ORDER        1535
#   630        52  POSSESSION_CONTROLLED_SUBSSTANCE         649
#   631        52                 POSSESSION_WEAPON         228
#   632        52                           ROBBERY         361
#   633        52                        SEX_CRIMES         146
#   634        52             SOCIAL_RELATED_CRIMES           3
#   635        52                             THEFT          50
#   636        52            TRAFFIC_LAWS_VIOLATION         138
#   637        52                      UNCLASSIFIED          49),
#  (60,      DISTRICT                        CRIME_TYPE  CMPLNT_NUM
#   638        60                             ARSON           9
#   639        60                           ASSAULT         920
#   640        60                          BURGLARY         122
#   641        60           DRIVING_UNDER_INFLUENCE          76
#   642        60                             FRAUD         114
#   643        60                          GAMBLING           2
#   644        60                       HARRASSMENT         842
#   645        60                        KIDNAPPING           1
#   646        60                           LARCENY        1391
#   647        60                    MISC_PENAL_LAW         260
#   648        60                            MURDER           6
#   649        60     OFFENSES_AGAINST_PUBLIC_ORDER         986
#   650        60  POSSESSION_CONTROLLED_SUBSSTANCE         239
#   651        60                 POSSESSION_WEAPON         164
#   652        60                           ROBBERY         122
#   653        60                        SEX_CRIMES         114
#   654        60             SOCIAL_RELATED_CRIMES           3
#   655        60                             THEFT          53
#   656        60            TRAFFIC_LAWS_VIOLATION          57
#   657        60                      UNCLASSIFIED          22),
#  (61,      DISTRICT                        CRIME_TYPE  CMPLNT_NUM
#   658        61                             ARSON           3
#   659        61                           ASSAULT         719
#   660        61                          BURGLARY         193
#   661        61           DRIVING_UNDER_INFLUENCE          90
#   662        61                             FRAUD         137
#   663        61                          GAMBLING           1
#   664        61                       HARRASSMENT         610
#   665        61                        KIDNAPPING           2
#   666        61                           LARCENY        1671
#   667        61                    MISC_PENAL_LAW         235
#   668        61                            MURDER           3
#   669        61     OFFENSES_AGAINST_PUBLIC_ORDER         794
#   670        61  POSSESSION_CONTROLLED_SUBSSTANCE          74
#   671        61                 POSSESSION_WEAPON          71
#   672        61                           ROBBERY         141
#   673        61                        SEX_CRIMES          85
#   674        61                             THEFT          13
#   675        61            TRAFFIC_LAWS_VIOLATION         119
#   676        61                      UNCLASSIFIED          17),
#  (62,      DISTRICT                        CRIME_TYPE  CMPLNT_NUM
#   677        62                             ARSON           6
#   678        62                           ASSAULT         693
#   679        62                          BURGLARY         203
#   680        62           DRIVING_UNDER_INFLUENCE          60
#   681        62                             FRAUD          84
#   682        62                       HARRASSMENT         856
#   683        62                        KIDNAPPING           1
#   684        62                           LARCENY        1825
#   685        62                    MISC_PENAL_LAW         212
#   686        62     OFFENSES_AGAINST_PUBLIC_ORDER         899
#   687        62  POSSESSION_CONTROLLED_SUBSSTANCE          96
#   688        62                 POSSESSION_WEAPON          55
#   689        62                           ROBBERY         132
#   690        62                        SEX_CRIMES          82
#   691        62             SOCIAL_RELATED_CRIMES           1
#   692        62                             THEFT          20
#   693        62            TRAFFIC_LAWS_VIOLATION          61
#   694        62                      UNCLASSIFIED          22),
#  (63,      DISTRICT                        CRIME_TYPE  CMPLNT_NUM
#   695        63                             ARSON           6
#   696        63                           ASSAULT         501
#   697        63                          BURGLARY         109
#   698        63           DRIVING_UNDER_INFLUENCE          49
#   699        63                             FRAUD         114
#   700        63                       HARRASSMENT         572
#   701        63                           LARCENY        1413
#   702        63                    MISC_PENAL_LAW         169
#   703        63                            MURDER           2
#   704        63     OFFENSES_AGAINST_PUBLIC_ORDER         613
#   705        63  POSSESSION_CONTROLLED_SUBSSTANCE          26
#   706        63                 POSSESSION_WEAPON         132
#   707        63                           ROBBERY          75
#   708        63                        SEX_CRIMES          74
#   709        63             SOCIAL_RELATED_CRIMES           4
#   710        63                             THEFT          18
#   711        63            TRAFFIC_LAWS_VIOLATION          56
#   712        63                      UNCLASSIFIED           8),
#  (66,      DISTRICT                        CRIME_TYPE  CMPLNT_NUM
#   713        66                             ARSON           5
#   714        66                           ASSAULT         551
#   715        66                          BURGLARY         190
#   716        66           DRIVING_UNDER_INFLUENCE          64
#   717        66                             FRAUD          46
#   718        66                          GAMBLING           7
#   719        66                       HARRASSMENT         584
#   720        66                        KIDNAPPING           1
#   721        66                           LARCENY        1394
#   722        66                    MISC_PENAL_LAW         142
#   723        66                            MURDER           2
#   724        66     OFFENSES_AGAINST_PUBLIC_ORDER         649
#   725        66  POSSESSION_CONTROLLED_SUBSSTANCE          39
#   726        66                 POSSESSION_WEAPON          51
#   727        66                           ROBBERY         116
#   728        66                        SEX_CRIMES          82
#   729        66                             THEFT          15
#   730        66            TRAFFIC_LAWS_VIOLATION          85
#   731        66                      UNCLASSIFIED          11),
# ...
#   1205       106                        SEX_CRIMES          84
#   1206       106             SOCIAL_RELATED_CRIMES          20
#   1207       106                             THEFT          21
#   1208       106            TRAFFIC_LAWS_VIOLATION         146
#   1209       106                      UNCLASSIFIED          27),
#  (107,       DISTRICT                        CRIME_TYPE  CMPLNT_NUM
#   1210       107                             ARSON           6
#   1211       107                           ASSAULT         647
#   1212       107                          BURGLARY         249
#   1213       107           DRIVING_UNDER_INFLUENCE          45
#   1214       107                             FRAUD          91
#   1215       107                       HARRASSMENT         827
#   1216       107                           LARCENY        1368
#   1217       107                    MISC_PENAL_LAW         148
#   1218       107                            MURDER           2
#   1219       107     OFFENSES_AGAINST_PUBLIC_ORDER        1041
#   1220       107  POSSESSION_CONTROLLED_SUBSSTANCE          38
#   1221       107                 POSSESSION_WEAPON          67
#   1222       107                           ROBBERY         158
#   1223       107                        SEX_CRIMES          86
#   1224       107             SOCIAL_RELATED_CRIMES           4
#   1225       107                             THEFT          24
#   1226       107            TRAFFIC_LAWS_VIOLATION          76
#   1227       107                      UNCLASSIFIED          11),
#  (108,       DISTRICT                        CRIME_TYPE  CMPLNT_NUM
#   1228       108                             ARSON           4
#   1229       108                           ASSAULT         674
#   1230       108                          BURGLARY         113
#   1231       108           DRIVING_UNDER_INFLUENCE          73
#   1232       108                             FRAUD         162
#   1233       108                       HARRASSMENT         834
#   1234       108                        KIDNAPPING           2
#   1235       108                           LARCENY        1440
#   1236       108                    MISC_PENAL_LAW         113
#   1237       108     OFFENSES_AGAINST_PUBLIC_ORDER         599
#   1238       108  POSSESSION_CONTROLLED_SUBSSTANCE          78
#   1239       108                 POSSESSION_WEAPON          39
#   1240       108                           ROBBERY         100
#   1241       108                        SEX_CRIMES          99
#   1242       108                             THEFT          42
#   1243       108            TRAFFIC_LAWS_VIOLATION          97
#   1244       108                      UNCLASSIFIED          12),
#  (109,       DISTRICT                        CRIME_TYPE  CMPLNT_NUM
#   1245       109                             ARSON           8
#   1246       109                           ASSAULT        1044
#   1247       109                          BURGLARY         432
#   1248       109           DRIVING_UNDER_INFLUENCE          68
#   1249       109                             FRAUD         143
#   1250       109                       HARRASSMENT        1395
#   1251       109                           LARCENY        3109
#   1252       109                    MISC_PENAL_LAW         264
#   1253       109                            MURDER           3
#   1254       109     OFFENSES_AGAINST_PUBLIC_ORDER        1028
#   1255       109  POSSESSION_CONTROLLED_SUBSSTANCE         107
#   1256       109                 POSSESSION_WEAPON          98
#   1257       109                           ROBBERY         209
#   1258       109                        SEX_CRIMES         117
#   1259       109             SOCIAL_RELATED_CRIMES           6
#   1260       109                             THEFT          53
#   1261       109            TRAFFIC_LAWS_VIOLATION         123
#   1262       109                      UNCLASSIFIED          23),
#  (110,       DISTRICT                        CRIME_TYPE  CMPLNT_NUM
#   1263       110                             ARSON           5
#   1264       110                           ASSAULT        1242
#   1265       110                          BURGLARY         172
#   1266       110           DRIVING_UNDER_INFLUENCE          50
#   1267       110                             FRAUD         100
#   1268       110                          GAMBLING           3
#   1269       110                       HARRASSMENT         975
#   1270       110                        KIDNAPPING           1
#   1271       110                           LARCENY        2401
#   1272       110                    MISC_PENAL_LAW         152
#   1273       110                            MURDER           2
#   1274       110     OFFENSES_AGAINST_PUBLIC_ORDER         814
#   1275       110  POSSESSION_CONTROLLED_SUBSSTANCE          82
#   1276       110                 POSSESSION_WEAPON          55
#   1277       110                           ROBBERY         272
#   1278       110                        SEX_CRIMES         147
#   1279       110             SOCIAL_RELATED_CRIMES           1
#   1280       110                             THEFT          35
#   1281       110            TRAFFIC_LAWS_VIOLATION         110
#   1282       110                      UNCLASSIFIED          12),
#  (111,       DISTRICT                        CRIME_TYPE  CMPLNT_NUM
#   1283       111                             ARSON           3
#   1284       111                           ASSAULT         277
#   1285       111                          BURGLARY         210
#   1286       111           DRIVING_UNDER_INFLUENCE          40
#   1287       111                             FRAUD          90
#   1288       111                       HARRASSMENT         431
#   1289       111                           LARCENY         835
#   1290       111                    MISC_PENAL_LAW          76
#   1291       111     OFFENSES_AGAINST_PUBLIC_ORDER         380
#   1292       111  POSSESSION_CONTROLLED_SUBSSTANCE          29
#   1293       111                 POSSESSION_WEAPON          19
#   1294       111                           ROBBERY          25
#   1295       111                        SEX_CRIMES          38
#   1296       111                             THEFT           9
#   1297       111            TRAFFIC_LAWS_VIOLATION          53
#   1298       111                      UNCLASSIFIED           5),
#  (112,       DISTRICT                        CRIME_TYPE  CMPLNT_NUM
#   1299       112                             ARSON           3
#   1300       112                           ASSAULT         305
#   1301       112                          BURGLARY          65
#   1302       112           DRIVING_UNDER_INFLUENCE         104
#   1303       112                             FRAUD          77
#   1304       112                       HARRASSMENT         473
#   1305       112                           LARCENY        1336
#   1306       112                    MISC_PENAL_LAW          60
#   1307       112     OFFENSES_AGAINST_PUBLIC_ORDER         487
#   1308       112  POSSESSION_CONTROLLED_SUBSSTANCE          14
#   1309       112                 POSSESSION_WEAPON          34
#   1310       112                           ROBBERY          40
#   1311       112                        SEX_CRIMES          63
#   1312       112                             THEFT          10
#   1313       112            TRAFFIC_LAWS_VIOLATION          67
#   1314       112                      UNCLASSIFIED           9),
#  (113,       DISTRICT                        CRIME_TYPE  CMPLNT_NUM
#   1315       113                             ARSON          14
#   1316       113                           ASSAULT        1334
#   1317       113                          BURGLARY         240
#   1318       113           DRIVING_UNDER_INFLUENCE          64
#   1319       113                             FRAUD         307
#   1320       113                       HARRASSMENT        1132
#   1321       113                        KIDNAPPING           1
#   1322       113                           LARCENY        1576
#   1323       113                    MISC_PENAL_LAW         374
#   1324       113                            MURDER          14
#   1325       113     OFFENSES_AGAINST_PUBLIC_ORDER        1326
#   1326       113  POSSESSION_CONTROLLED_SUBSSTANCE         141
#   1327       113                 POSSESSION_WEAPON         291
#   1328       113                           ROBBERY         156
#   1329       113                        SEX_CRIMES         112
#   1330       113             SOCIAL_RELATED_CRIMES           5
#   1331       113                             THEFT          48
#   1332       113            TRAFFIC_LAWS_VIOLATION         167
#   1333       113                      UNCLASSIFIED          39),
#  (114,       DISTRICT                        CRIME_TYPE  CMPLNT_NUM
#   1334       114                             ARSON           8
#   1335       114                           ASSAULT        1327
#   1336       114                          BURGLARY         254
#   1337       114           DRIVING_UNDER_INFLUENCE          86
#   1338       114                             FRAUD         165
#   1339       114                       HARRASSMENT        1250
#   1340       114                           LARCENY        2327
#   1341       114                    MISC_PENAL_LAW         362
#   1342       114                            MURDER           1
#   1343       114     OFFENSES_AGAINST_PUBLIC_ORDER        1375
#   1344       114  POSSESSION_CONTROLLED_SUBSSTANCE         126
#   1345       114                 POSSESSION_WEAPON         128
#   1346       114                           ROBBERY         184
#   1347       114                        SEX_CRIMES         163
#   1348       114             SOCIAL_RELATED_CRIMES           9
#   1349       114                             THEFT          49
#   1350       114            TRAFFIC_LAWS_VIOLATION         161
#   1351       114                      UNCLASSIFIED          26),
#  (115,       DISTRICT                        CRIME_TYPE  CMPLNT_NUM
#   1352       115                             ARSON          11
#   1353       115                           ASSAULT        1469
#   1354       115                          BURGLARY         183
#   1355       115           DRIVING_UNDER_INFLUENCE         123
#   1356       115                             FRAUD         172
#   1357       115                       HARRASSMENT        1067
#   1358       115                        KIDNAPPING          10
#   1359       115                           LARCENY        1801
#   1360       115                    MISC_PENAL_LAW         283
#   1361       115                            MURDER          11
#   1362       115     OFFENSES_AGAINST_PUBLIC_ORDER        1025
#   1363       115  POSSESSION_CONTROLLED_SUBSSTANCE         150
#   1364       115                 POSSESSION_WEAPON         299
#   1365       115                           ROBBERY         245
#   1366       115                        SEX_CRIMES         237
#   1367       115             SOCIAL_RELATED_CRIMES           4
#   1368       115                             THEFT          69
#   1369       115            TRAFFIC_LAWS_VIOLATION         124
#   1370       115                      UNCLASSIFIED          30),
#  (120,       DISTRICT                        CRIME_TYPE  CMPLNT_NUM
#   1371       120                             ARSON          15
#   1372       120                           ASSAULT        1103
#   1373       120                          BURGLARY         146
#   1374       120           DRIVING_UNDER_INFLUENCE         130
#   1375       120                             FRAUD         111
#   1376       120                          GAMBLING           1
#   1377       120                       HARRASSMENT        1485
#   1378       120                        KIDNAPPING           4
#   1379       120                           LARCENY        1129
#   1380       120                    MISC_PENAL_LAW         361
#   1381       120                            MURDER           4
#   1382       120     OFFENSES_AGAINST_PUBLIC_ORDER        1511
#   1383       120  POSSESSION_CONTROLLED_SUBSSTANCE         243
#   1384       120                 POSSESSION_WEAPON         163
#   1385       120                           ROBBERY          94
#   1386       120                        SEX_CRIMES         104
#   1387       120             SOCIAL_RELATED_CRIMES           4
#   1388       120                             THEFT          37
#   1389       120            TRAFFIC_LAWS_VIOLATION          42
#   1390       120                      UNCLASSIFIED          28),
#  (121,       DISTRICT                        CRIME_TYPE  CMPLNT_NUM
#   1391       121                             ARSON           5
#   1392       121                           ASSAULT         743
#   1393       121                          BURGLARY         134
#   1394       121           DRIVING_UNDER_INFLUENCE         293
#   1395       121                             FRAUD         122
#   1396       121                       HARRASSMENT        1032
#   1397       121                           LARCENY        1420
#   1398       121                    MISC_PENAL_LAW         224
#   1399       121                            MURDER           2
#   1400       121     OFFENSES_AGAINST_PUBLIC_ORDER        1104
#   1401       121  POSSESSION_CONTROLLED_SUBSSTANCE          92
#   1402       121                 POSSESSION_WEAPON          72
#   1403       121                           ROBBERY          81
#   1404       121                        SEX_CRIMES          63
#   1405       121             SOCIAL_RELATED_CRIMES           8
#   1406       121                             THEFT          15
#   1407       121            TRAFFIC_LAWS_VIOLATION          47
#   1408       121                      UNCLASSIFIED          44),
#  (122,       DISTRICT                        CRIME_TYPE  CMPLNT_NUM
#   1409       122                             ARSON           9
#   1410       122                           ASSAULT         487
#   1411       122                          BURGLARY         105
#   1412       122           DRIVING_UNDER_INFLUENCE         125
#   1413       122                             FRAUD         142
#   1414       122                       HARRASSMENT        1069
#   1415       122                           LARCENY         894
#   1416       122                    MISC_PENAL_LAW         238
#   1417       122                            MURDER           6
#   1418       122     OFFENSES_AGAINST_PUBLIC_ORDER         801
#   1419       122  POSSESSION_CONTROLLED_SUBSSTANCE          98
#   1420       122                 POSSESSION_WEAPON          52
#   1421       122                           ROBBERY          40
#   1422       122                        SEX_CRIMES          56
#   1423       122             SOCIAL_RELATED_CRIMES           4
#   1424       122                             THEFT          30
#   1425       122            TRAFFIC_LAWS_VIOLATION          58
#   1426       122                      UNCLASSIFIED          26),
#  (123,       DISTRICT                        CRIME_TYPE  CMPLNT_NUM
#   1427       123                             ARSON           3
#   1428       123                           ASSAULT         227
#   1429       123                          BURGLARY          55
#   1430       123           DRIVING_UNDER_INFLUENCE          96
#   1431       123                             FRAUD          74
#   1432       123                       HARRASSMENT         443
#   1433       123                           LARCENY         447
#   1434       123                    MISC_PENAL_LAW          56
#   1435       123                            MURDER           3
#   1436       123     OFFENSES_AGAINST_PUBLIC_ORDER         491
#   1437       123  POSSESSION_CONTROLLED_SUBSSTANCE          54
#   1438       123                 POSSESSION_WEAPON          36
#   1439       123                           ROBBERY          12
#   1440       123                        SEX_CRIMES          21
#   1441       123                             THEFT          11
#   1442       123            TRAFFIC_LAWS_VIOLATION          18
#   1443       123                      UNCLASSIFIED          23)]

# %%
# Using Lambda
# In a groupby you have a bunch of groups. `groupby.apply()` iterates through each group in a groupby and applies some function to it.

# Here, we are going to iterate through each DISTRICT group 
# and find the row in the "OFFENSE_NAME" column where the CMPLNT_NUM is the max 

# So this is like saying 
# result = precincts.apply(lambda group: column[row])
# where `column` is group.OFFENSE_NAME column 
# and `row` is the row index where CMPLNT_NUM is max

result = districts.apply(lambda group: group.CRIME_TYPE[group.CMPLNT_NUM.idxmax()])

# %%
# Print most frequent crime in each precinct
result = result.rename(columns={0: 'MOST_FREQ_CRIME'})
result
# Out:
# DISTRICT
# 1                            LARCENY
# 5                            LARCENY
# 6                            LARCENY
# 7                            LARCENY
# 9                            LARCENY
#                    ...
# 115                          LARCENY
# 120    OFFENSES_AGAINST_PUBLIC_ORDER
# 121                          LARCENY
# 122                      HARRASSMENT
# 123    OFFENSES_AGAINST_PUBLIC_ORDER
# Length: 77, dtype: object

# %%
# Plot Results

# %% [markdown]
# ## Plot the frequency of top 10 crimes committed
# I want to see the nature of crimes being reported by plotting the top 10 most frequent crime reported.

# %%
# Get the top 10 crime types with high frequency
top_10_crimes = df.CRIME_TYPE.value_counts().head(10)

# Sort in descending order
top_10_crimes= top_10_crimes[::-1]

# Plot using horizontal bar chart
ax = top_10_crimes.plot(kind='barh')
ax.set(xlabel= "Number of Crimes", ylabel="Crime")
# Out:
# [Text(0, 0.5, 'Crime'), Text(0.5, 0, 'Number of Crimes')]

# %% [markdown]
# There is a mix of violent and non violent crimes reported. Larceny, offenses againts public order and Assault are leading. Studies have shown that victims will most likely report a crime if it is violent. The data justifies it.

# %% [markdown]
# ## Make a bar graph of Felony vs Misdemeanor vs Violation
# I would like to see the offense level of crimes reported each month. I used unstacked bar graph to see the trends in each offense level.

# %%
# Plot the offense level occurence in each month
fig, ax = plt.subplots(figsize=(14,6))
crime_lvl = df[['MONTH','OFFENSE LEVEL']]
ax = sns.countplot(x="MONTH",
                   hue='OFFENSE LEVEL',
                   data=crime_lvl,
                   palette="PuBuGn_d")
plt.title('FELONY VS MISDEMEANOR VS VIOLATION')
# Out:
# Text(0.5, 1.0, 'FELONY VS MISDEMEANOR VS VIOLATION')

# %% [markdown]
# Looks like Misdemeanor is the top offense category of the crimes in NYC. This is better than having the majority of the crimes be felonies.
#
# You can see a general trend in the data, where as Misdeameanors increase and decrease, so do Felonies and Violations. This also relates back to the Time-Series plots we made for total crimes reported each month.

# %% [markdown]
# ## Make a Stacked Bar Graph of Top 5 Crimes in 2019
# I would like to see the distribution of crimes reported each month but due to various of crime being reported, it will be huge data to plot. We can cee this minute scale by plotting only the top 5 most crimes reported each month.

# %%
#Filter df only where rows are the top 5 crimes using .loc  
top_10_crimes = df.OFFENSE_NAME.value_counts().head(5).index.tolist()
df2 = df.loc[df['OFFENSE_NAME'].isin(top_10_crimes)]


df2 = df2.groupby(['MONTH', 'OFFENSE_NAME'])['MONTH'].count().unstack()
df2.head()
# Out:
# OFFENSE_NAME  ASSAULT 3 & RELATED OFFENSES  CRIMINAL MISCHIEF & RELATED OF  \
# MONTH
# 1                                     3899                            3999
# 2                                     3633                            3231
# 3                                     4231                            3950
# 4                                     4285                            3578
# 5                                     5078                            4090
#
# OFFENSE_NAME  GRAND LARCENY  HARRASSMENT 2  PETIT LARCENY
# MONTH
# 1                      3200           5415           6603
# 2                      2771           4941           5872
# 3                      3118           5745           6509
# 4                      3137           5940           6788
# 5                      3528           6440           7290

# %%
# Plot Stacked Bar Graph
ax = df2.plot(kind='bar',legend="best", figsize=(16,8))
ax.set(xlabel="MONTH", ylabel="count")
# ax.legend(pos="center")
# Out:
# [Text(0, 0.5, 'count'), Text(0.5, 0, 'MONTH')]

# %% [markdown]
# ## Conclusion
#
# I used data compiled by the New York police department to extract some insights on crimes reported in New York Metropolitan Area. While the data analysis performed here is devoid of a national perspective my key findings can be distilled to a few key points below:
#
# - Brooklyn has the highest crime reported with 29% of total reports. That makes sense since Brooklyn is the most populated borough according to (https://guides.lib.jjay.cuny.edu/c.php?g=288385&p=1922495).
# - The trends of the crime reports in all boroughs are consistent throughout the year. All boroughs have the same months of high and low reports. No overlapping of data trends had occurred.
# - Brooklyn as being the one with the highest reports is also consistent to be the highest portion in overall's monthly total in 2019.
# - Interestingly, District 75 in Brooklyn had the most crimes reported followed by District 40, 44 and 52 which are in the Bronx. Manhattan has the second-highest reports overall.
# - All districts in NYC have crimes reported.
# - Theft and Harassment were racing with each other throughout the entire month
# - The top 10 most crimes reported include larceny, harassment, and assault.
# - The most frequent offense level of all crimes reported is a misdemeanor and the general trend of felonies and violations follows it throughout the whole year.
# - During hot weather, reports are more frequent compared to the cold season. Reports drop drastically as holidays approach.
#
# While these observations are illuminating, I should mention that they don't paint the whole picture and comparisons should be made with national or other comparable data including crime data from other cities to give more perspective. We don't know if the total crime reports are within the national average or too high. Such comparisons would help us build more compelling arguments in our data storytelling by using them to support our local findings.
#
# With that being said, our findings are still very relevant to the new detectives and residents of NYC for local decision making on how to lessen the crime reports in each borough.
